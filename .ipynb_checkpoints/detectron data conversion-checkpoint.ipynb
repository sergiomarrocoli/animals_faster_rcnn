# %%
import os
import numpy as np
import json
import csv
import pandas as pd
import random

# %%
# You may need to restart your runtime prior to this, to let your installation take effect
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import cv2
import random
# from google.colab.patches import cv2_imshow

# import some common detectron2 utilities
from detectron2.structures import BoxMode
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import DatasetCatalog, MetadataCatalog

# %%
def get_animals_dicts(img_dir):
        
    csv_file = os.path.join(img_dir, "2020-02-14.csv")
    imgs_anns = pd.read_csv(csv_file, sep= ",", header=0)
    classes = list(set(imgs_anns['species']))
    
    dataset_dicts = []

    imgs_anns = imgs_anns.sample(frac=1)
    files = list(set(imgs_anns['file']))
    random.shuffle(files)
    dataset_dicts = []
    
    idx = 0
    
    for file in files:
        data = imgs_anns[imgs_anns['file'] == file]

        record = {}

        record["file_name"] = file
        record["image_id"] = idx
        idx += 1
        record["height"] = int(data['height'][:1])
        record["width"] = int(data['width'][:1])


        objs = []
        for index, row in data.iterrows():
            obj = {
                "bbox": [int(row['x']), int(row['y']), int(row['w']), int(row['h'])],
                "bbox_mode": BoxMode.XYXY_ABS,
                "category_id": classes.index(row['species']),
                "iscrowd": 0
            }
            objs.append(obj)
        record["annotations"] = objs
        dataset_dicts.append(record)
    return dataset_dicts

# %%
for d in ["training", "val"]:
    DatasetCatalog.register("animals_" + d, lambda d=d: get_animals_dicts("animals_" + d + "/"))
    csv_file = os.path.join("animals_" + d, "2020-02-14.csv")
    imgs_anns = pd.read_csv(csv_file, sep= ",", header=0)
    classes = list(set(imgs_anns['species']))
    MetadataCatalog.get("animals_" + d).set(thing_classes=classes)
animal_metadata = MetadataCatalog.get("animals_training")

# %%
import random
from detectron2.utils.visualizer import Visualizer

dataset_dicts = get_animals_dicts('animals_training')

for d in random.sample(dataset_dicts, 3):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=animal_metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    cv2.imshow('', vis.get_image()[:, :, ::-1])
    cv2.waitKey(0) # waits until a key is pressed
    cv2.destroyAllWindows() # destroys the window showing image

# %%
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("animals_training",)
cfg.DATASETS.TEST = ()
cfg.DATALOADER.NUM_WORKERS = 1
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x.yaml")  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.BASE_LR = 0.00025  # pick a good LR
cfg.SOLVER.MAX_ITER = 1000    # 300 iterations seems good enough for this toy dataset; you may need to train longer for a practical dataset
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 512   # faster, and good enough for this toy dataset (default: 512)
cfg.MODEL.ROI_HEADS.NUM_CLASSES = len(MetadataCatalog.get("animals_training").thing_classes)  # only has one class (ballon)

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = DefaultTrainer(cfg) 
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [02/22 16:21:07 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=3, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=8, bias=True)
#     )
#   )
# )
# [02/22 16:21:08 d2.data.build]: Removed 0 images with no usable annotations. 998 images left.
# [02/22 16:21:08 d2.data.build]: Distribution of instances among all 2 categories:
# |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|
# |  elephant  | 500          | chimpanzee | 500          |
# |            |              |            |              |
# |   total    | 1000         |            |              |
# [02/22 16:21:08 d2.data.detection_utils]: TransformGens used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [02/22 16:21:08 d2.data.build]: Using training sampler TrainingSampler
# /home/sergio/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/sergio/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/sergio/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/sergio/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/sergio/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/sergio/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 'roi_heads.box_predictor.cls_score.weight' has shape (81, 1024) in the checkpoint but (3, 1024) in the model! Skipped.
# 'roi_heads.box_predictor.cls_score.bias' has shape (81,) in the checkpoint but (3,) in the model! Skipped.
# 'roi_heads.box_predictor.bbox_pred.weight' has shape (320, 1024) in the checkpoint but (8, 1024) in the model! Skipped.
# 'roi_heads.box_predictor.bbox_pred.bias' has shape (320,) in the checkpoint but (8,) in the model! Skipped.
# [02/22 16:21:09 d2.engine.train_loop]: Starting training from iteration 0
# [02/22 16:21:27 d2.utils.events]: eta: 0:04:06  iter: 19  total_loss: 1.570  loss_cls: 1.006  loss_box_reg: 0.544  loss_rpn_cls: 0.002  loss_rpn_loc: 0.003  time: 0.8802  data_time: 0.0122  lr: 0.000005  max_mem: 6051M
# [02/22 16:21:46 d2.utils.events]: eta: 0:03:55  iter: 39  total_loss: 1.387  loss_cls: 0.903  loss_box_reg: 0.492  loss_rpn_cls: 0.009  loss_rpn_loc: 0.008  time: 0.9130  data_time: 0.0039  lr: 0.000010  max_mem: 6051M
# [02/22 16:22:04 d2.utils.events]: eta: 0:03:38  iter: 59  total_loss: 1.253  loss_cls: 0.722  loss_box_reg: 0.535  loss_rpn_cls: 0.006  loss_rpn_loc: 0.006  time: 0.9085  data_time: 0.0035  lr: 0.000015  max_mem: 6051M
# [02/22 16:22:21 d2.utils.events]: eta: 0:03:18  iter: 79  total_loss: 1.158  loss_cls: 0.583  loss_box_reg: 0.528  loss_rpn_cls: 0.004  loss_rpn_loc: 0.005  time: 0.8991  data_time: 0.0034  lr: 0.000020  max_mem: 6051M
# [02/22 16:22:39 d2.utils.events]: eta: 0:03:01  iter: 99  total_loss: 1.054  loss_cls: 0.470  loss_box_reg: 0.534  loss_rpn_cls: 0.013  loss_rpn_loc: 0.004  time: 0.8996  data_time: 0.0034  lr: 0.000025  max_mem: 6051M
# [02/22 16:22:58 d2.utils.events]: eta: 0:02:43  iter: 119  total_loss: 0.974  loss_cls: 0.431  loss_box_reg: 0.522  loss_rpn_cls: 0.006  loss_rpn_loc: 0.005  time: 0.9013  data_time: 0.0035  lr: 0.000030  max_mem: 6243M
# [02/22 16:23:16 d2.utils.events]: eta: 0:02:25  iter: 139  total_loss: 0.886  loss_cls: 0.368  loss_box_reg: 0.488  loss_rpn_cls: 0.001  loss_rpn_loc: 0.006  time: 0.9022  data_time: 0.0035  lr: 0.000035  max_mem: 6243M
# [02/22 16:23:35 d2.utils.events]: eta: 0:02:08  iter: 159  total_loss: 0.958  loss_cls: 0.375  loss_box_reg: 0.563  loss_rpn_cls: 0.010  loss_rpn_loc: 0.005  time: 0.9072  data_time: 0.0035  lr: 0.000040  max_mem: 6243M
# [02/22 16:23:53 d2.utils.events]: eta: 0:01:50  iter: 179  total_loss: 0.841  loss_cls: 0.338  loss_box_reg: 0.532  loss_rpn_cls: 0.003  loss_rpn_loc: 0.005  time: 0.9105  data_time: 0.0038  lr: 0.000045  max_mem: 6243M
# [02/22 16:24:12 d2.utils.events]: eta: 0:01:32  iter: 199  total_loss: 0.879  loss_cls: 0.318  loss_box_reg: 0.532  loss_rpn_cls: 0.001  loss_rpn_loc: 0.005  time: 0.9106  data_time: 0.0034  lr: 0.000050  max_mem: 6243M
# [02/22 16:24:30 d2.utils.events]: eta: 0:01:14  iter: 219  total_loss: 0.866  loss_cls: 0.332  loss_box_reg: 0.520  loss_rpn_cls: 0.004  loss_rpn_loc: 0.005  time: 0.9104  data_time: 0.0034  lr: 0.000055  max_mem: 6243M
# [02/22 16:24:48 d2.utils.events]: eta: 0:00:55  iter: 239  total_loss: 0.861  loss_cls: 0.282  loss_box_reg: 0.581  loss_rpn_cls: 0.002  loss_rpn_loc: 0.005  time: 0.9095  data_time: 0.0034  lr: 0.000060  max_mem: 6243M
# [02/22 16:25:06 d2.utils.events]: eta: 0:00:37  iter: 259  total_loss: 0.896  loss_cls: 0.295  loss_box_reg: 0.590  loss_rpn_cls: 0.001  loss_rpn_loc: 0.004  time: 0.9076  data_time: 0.0034  lr: 0.000065  max_mem: 6243M
# [02/22 16:25:23 d2.utils.events]: eta: 0:00:19  iter: 279  total_loss: 0.869  loss_cls: 0.275  loss_box_reg: 0.578  loss_rpn_cls: 0.001  loss_rpn_loc: 0.004  time: 0.9064  data_time: 0.0032  lr: 0.000070  max_mem: 6243M
# [02/22 16:25:45 d2.utils.events]: eta: 0:00:00  iter: 299  total_loss: 0.838  loss_cls: 0.253  loss_box_reg: 0.577  loss_rpn_cls: 0.003  loss_rpn_loc: 0.003  time: 0.9069  data_time: 0.0037  lr: 0.000075  max_mem: 6243M
# [02/22 16:25:46 d2.engine.hooks]: Overall training speed: 297 iterations in 0:04:30 (0.9100 s / it)
# [02/22 16:25:46 d2.engine.hooks]: Total training time: 0:04:34 (0:00:04 on hooks)

# %%
# Look at training curves in tensorboard:
# %load_ext tensorboard
# %tensorboard --logdir output
# Out:
#       <iframe id="tensorboard-frame-e1d83afc4ea43fff" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e1d83afc4ea43fff");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.3   # set the testing threshold for this model
cfg.DATASETS.TEST = ("animals_val", )
predictor = DefaultPredictor(cfg)

# %%
from detectron2.utils.visualizer import ColorMode
dataset_dicts = get_animals_dicts("animals_val")
for d in random.sample(dataset_dicts, 20):    
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1],
                   metadata=animal_metadata, 
                   scale=0.8   # remove the colors of unsegmented pixels
    )
    v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    cv2.imshow("",v.get_image()[:, :, ::-1])
    cv2.waitKey(0) # waits until a key is pressed
    cv2.destroyAllWindows() # destroys the window showing image

# %%
img_dir = "animals_training/"
csv_file = os.path.join(img_dir, "2020-02-14.csv")
imgs_anns = pd.read_csv(csv_file, sep= ",", header=0)
classes = list(set(imgs_anns['species']))

dataset_dicts = []

imgs_anns = imgs_anns.sample(frac=1)
files = list(set(imgs_anns['file']))

# %%
random.shuffle(files)

# %%
files
# Out:
# ['animals_training/ACP000dn0j_110.0.jpg',
#  'animals_training/ACP000dsmz_230.0.jpg',
#  'animals_training/ACP000d9yj_270.0.jpg',
#  'animals_training/ACP000dt6u_350.0.jpg',
#  'animals_training/ACP000d2pg_110.0.jpg',
#  'animals_training/ACP000cygq_100.0.jpg',
#  'animals_training/ACP000d3ne_140.0.jpg',
#  'animals_training/ACP000dlsg_300.0.jpg',
#  'animals_training/ACP000ceuw_300.0.jpg',
#  'animals_training/ACP00028ye_120.0.jpg',
#  'animals_training/ACP000drtb_270.0.jpg',
#  'animals_training/ACP000bmhx_130.0.jpg',
#  'animals_training/ACP000ccry_120.0.jpg',
#  'animals_training/ACP000dls4_150.0.jpg',
#  'animals_training/ACP000cnpq_330.0.jpg',
#  'animals_training/ACP000dkrq_240.0.jpg',
#  'animals_training/ACP000dl1t_270.0.jpg',
#  'animals_training/ACP000d72t_90.0.jpg',
#  'animals_training/ACP000dlhn_190.0.jpg',
#  'animals_training/ACP000dad0_100.0.jpg',
#  'animals_training/ACP000dt75_170.0.jpg',
#  'animals_training/ACP000dpfm_300.0.jpg',
#  'animals_training/ACP000djr7_50.0.jpg',
#  'animals_training/ACP000cggc_270.0.jpg',
#  'animals_training/ACP000djvt_140.0.jpg',
#  'animals_training/ACP000dtcz_110.0.jpg',
#  'animals_training/ACP000e3uv_170.0.jpg',
#  'animals_training/ACP000bd1p_180.0.jpg',
#  'animals_training/ACP000d70v_20.0.jpg',
#  'animals_training/ACP000dpyi_60.0.jpg',
#  'animals_training/ACP000bics_80.0.jpg',
#  'animals_training/ACP000djl2_350.0.jpg',
#  'animals_training/ACP000dchu_190.0.jpg',
#  'animals_training/ACP000buzd_30.0.jpg',
#  'animals_training/ACP000dsjx_150.0.jpg',
#  'animals_training/ACP000d73b_140.0.jpg',
#  'animals_training/ACP000ds72_260.0.jpg',
#  'animals_training/ACP000bj72_90.0.jpg',
#  'animals_training/ACP000bums_0.0.jpg',
#  'animals_training/ACP00054kp_330.0.jpg',
#  'animals_training/ACP000d6ii_80.0.jpg',
#  'animals_training/ACP000d0nd_110.0.jpg',
#  'animals_training/ACP000dnb9_320.0.jpg',
#  'animals_training/ACP000d6xn_350.0.jpg',
#  'animals_training/ACP000dcd5_230.0.jpg',
#  'animals_training/ACP00000ga_70.0.jpg',
#  'animals_training/ACP000dr5o_300.0.jpg',
#  'animals_training/ACP000do8s_210.0.jpg',
#  'animals_training/ACP000gbni_10.0.jpg',
#  'animals_training/ACP000cg5n_330.0.jpg',
#  'animals_training/ACP000cgj1_320.0.jpg',
#  'animals_training/ACP000dcfv_290.0.jpg',
#  'animals_training/ACP000d38u_90.0.jpg',
#  'animals_training/ACP000dphv_350.0.jpg',
#  'animals_training/ACP000dpiv_330.0.jpg',
#  'animals_training/ACP000d5xt_330.0.jpg',
#  'animals_training/ACP000d7lc_160.0.jpg',
#  'animals_training/ACP000djo8_30.0.jpg',
#  'animals_training/ACP000bid5_130.0.jpg',
#  'animals_training/ACP000bi60_0.0.jpg',
#  'animals_training/ACP000dovr_160.0.jpg',
#  'animals_training/ACP000d701_100.0.jpg',
#  'animals_training/ACP000dt9x_250.0.jpg',
#  'animals_training/ACP000cr6c_50.0.jpg',
#  'animals_training/ACP000d9ij_200.0.jpg',
#  'animals_training/ACP000djyr_130.0.jpg',
#  'animals_training/ACP000dljy_180.0.jpg',
#  'animals_training/ACP000cc0w_120.0.jpg',
#  'animals_training/ACP000d5y5_340.0.jpg',
#  'animals_training/ACP000d71i_10.0.jpg',
#  'animals_training/ACP000be2q_10.0.jpg',
#  'animals_training/ACP000d3nj_250.0.jpg',
#  'animals_training/ACP000cnq2_0.0.jpg',
#  'animals_training/ACP0003dsb_0.0.jpg',
#  'animals_training/ACP000dskl_210.0.jpg',
#  'animals_training/ACP000d6x8_100.0.jpg',
#  'animals_training/ACP000gbni_30.0.jpg',
#  'animals_training/ACP000dla3_20.0.jpg',
#  'animals_training/ACP000by8e_10.0.jpg',
#  'animals_training/ACP000dsnp_270.0.jpg',
#  'animals_training/ACP000dl4o_20.0.jpg',
#  'animals_training/ACP000ddsa_270.0.jpg',
#  'animals_training/ACP000bn0q_260.0.jpg',
#  'animals_training/ACP000d6wp_180.0.jpg',
#  'animals_training/ACP000d7xy_10.0.jpg',
#  'animals_training/ACP000fwcs_70.0.jpg',
#  'animals_training/ACP000d0ov_200.0.jpg',
#  'animals_training/ACP000dlpa_320.0.jpg',
#  'animals_training/ACP000d0o3_60.0.jpg',
#  'animals_training/ACP000dfjh_300.0.jpg',
#  'animals_training/ACP000dj1o_230.0.jpg',
#  'animals_training/ACP000fttq_180.0.jpg',
#  'animals_training/ACP000cnyn_0.0.jpg',
#  'animals_training/ACP000dveb_100.0.jpg',
#  'animals_training/ACP000dobu_130.0.jpg',
#  'animals_training/ACP000dofy_30.0.jpg',
#  'animals_training/ACP000djqi_160.0.jpg',
#  'animals_training/ACP000cimz_60.0.jpg',
#  'animals_training/ACP000dsa6_70.0.jpg',
#  'animals_training/ACP000dchw_100.0.jpg',
#  'animals_training/ACP000d0w4_40.0.jpg',
#  'animals_training/ACP000dpiv_50.0.jpg',
#  'animals_training/ACP000dku4_290.0.jpg',
#  'animals_training/ACP000dogr_50.0.jpg',
#  'animals_training/ACP000dl25_180.0.jpg',
#  'animals_training/ACP000dk4f_0.0.jpg',
#  'animals_training/ACP000dqzv_0.0.jpg',
#  'animals_training/ACP000dls5_70.0.jpg',
#  'animals_training/ACP0002ud1_50.0.jpg',
#  'animals_training/ACP000ds33_110.0.jpg',
#  'animals_training/ACP000bmvv_310.0.jpg',
#  'animals_training/ACP000dl26_70.0.jpg',
#  'animals_training/ACP000fc0d_30.0.jpg',
#  'animals_training/ACP000d6wj_310.0.jpg',
#  'animals_training/ACP000dstp_100.0.jpg',
#  'animals_training/ACP000224f_210.0.jpg',
#  'animals_training/ACP000d0mc_270.0.jpg',
#  'animals_training/ACP000021a_320.0.jpg',
#  'animals_training/ACP000g1b1_50.0.jpg',
#  'animals_training/ACP00028yz_250.0.jpg',
#  'animals_training/ACP000dvcz_270.0.jpg',
#  'animals_training/ACP000d3n1_110.0.jpg',
#  'animals_training/ACP000dmzr_130.0.jpg',
#  'animals_training/ACP000dsgx_130.0.jpg',
#  'animals_training/ACP00070n2_120.0.jpg',
#  'animals_training/ACP00070fv_340.0.jpg',
#  'animals_training/ACP000293j_170.0.jpg',
#  'animals_training/ACP000bu1s_210.0.jpg',
#  'animals_training/ACP00027m0_250.0.jpg',
#  'animals_training/ACP000dleu_260.0.jpg',
#  'animals_training/ACP000dsid_270.0.jpg',
#  'animals_training/ACP000cz1p_160.0.jpg',
#  'animals_training/ACP0004bin_310.0.jpg',
#  'animals_training/ACP000d71h_0.0.jpg',
#  'animals_training/ACP000c4cn_230.0.jpg',
#  'animals_training/ACP000dsh7_220.0.jpg',
#  'animals_training/ACP000do6d_310.0.jpg',
#  'animals_training/ACP000bi4i_0.0.jpg',
#  'animals_training/ACP000dqzd_20.0.jpg',
#  'animals_training/ACP000dti0_40.0.jpg',
#  'animals_training/ACP000d0gr_210.0.jpg',
#  'animals_training/ACP000delx_240.0.jpg',
#  'animals_training/ACP000byaa_240.0.jpg',
#  'animals_training/ACP000baty_100.0.jpg',
#  'animals_training/ACP00072k8_50.0.jpg',
#  'animals_training/ACP000cgby_120.0.jpg',
#  'animals_training/ACP000dfjb_50.0.jpg',
#  'animals_training/ACP000b3e6_180.0.jpg',
#  'animals_training/ACP000cnyp_50.0.jpg',
#  'animals_training/ACP000d3pa_330.0.jpg',
#  'animals_training/ACP000d0fj_260.0.jpg',
#  'animals_training/ACP000drb8_0.0.jpg',
#  'animals_training/ACP0004j74_110.0.jpg',
#  'animals_training/ACP000dtbh_340.0.jpg',
#  'animals_training/ACP000djzm_10.0.jpg',
#  'animals_training/ACP000ctxc_50.0.jpg',
#  'animals_training/ACP000cgfy_280.0.jpg',
#  'animals_training/ACP000ds71_180.0.jpg',
#  'animals_training/ACP000d7u3_90.0.jpg',
#  'animals_training/ACP000ctqh_80.0.jpg',
#  'animals_training/ACP000ds94_60.0.jpg',
#  'animals_training/ACP000dsbr_30.0.jpg',
#  'animals_training/ACP000bu1s_240.0.jpg',
#  'animals_training/ACP000dcfr_190.0.jpg',
#  'animals_training/ACP000cmti_340.0.jpg',
#  'animals_training/ACP000dlrp_290.0.jpg',
#  'animals_training/ACP000d0bu_230.0.jpg',
#  'animals_training/ACP000do4w_260.0.jpg',
#  'animals_training/ACP000dr1a_180.0.jpg',
#  'animals_training/ACP000doaw_310.0.jpg',
#  'animals_training/ACP000d5w8_260.0.jpg',
#  'animals_training/ACP000d6gx_190.0.jpg',
#  'animals_training/ACP000dri6_130.0.jpg',
#  'animals_training/ACP00056ek_50.0.jpg',
#  'animals_training/ACP000b68w_280.0.jpg',
#  'animals_training/ACP000d9im_350.0.jpg',
#  'animals_training/ACP000do5p_240.0.jpg',
#  'animals_training/ACP000dodi_170.0.jpg',
#  'animals_training/ACP000bn36_240.0.jpg',
#  'animals_training/ACP000d73d_160.0.jpg',
#  'animals_training/ACP000bfqs_240.0.jpg',
#  'animals_training/ACP000buzi_100.0.jpg',
#  'animals_training/ACP000bfpe_240.0.jpg',
#  'animals_training/ACP000dtol_30.0.jpg',
#  'animals_training/ACP000cpau_80.0.jpg',
#  'animals_training/ACP000dtd1_120.0.jpg',
#  'animals_training/ACP000drb5_60.0.jpg',
#  'animals_training/ACP000cgc0_30.0.jpg',
#  'animals_training/ACP000d5re_50.0.jpg',
#  'animals_training/ACP0003szb_180.0.jpg',
#  'animals_training/ACP000emi7_150.0.jpg',
#  'animals_training/ACP000d0bu_310.0.jpg',
#  'animals_training/ACP000cghl_100.0.jpg',
#  'animals_training/ACP0004tbw_0.0.jpg',
#  'animals_training/ACP000cbhh_10.0.jpg',
#  'animals_training/ACP000cgfz_130.0.jpg',
#  'animals_training/ACP000dql0_40.0.jpg',
#  'animals_training/ACP000cg5o_220.0.jpg',
#  'animals_training/ACP000dr9h_180.0.jpg',
#  'animals_training/ACP000d9mr_310.0.jpg',
#  'animals_training/ACP000b6ra_300.0.jpg',
#  'animals_training/ACP000bmhx_190.0.jpg',
#  'animals_training/ACP000dtr6_350.0.jpg',
#  'animals_training/ACP0005uiz_330.0.jpg',
#  'animals_training/ACP000cr6c_60.0.jpg',
#  'animals_training/ACP00038us_30.0.jpg',
#  'animals_training/ACP000cnpq_210.0.jpg',
#  'animals_training/ACP0004tc2_290.0.jpg',
#  'animals_training/ACP000cnq2_70.0.jpg',
#  'animals_training/ACP000dlle_100.0.jpg',
#  'animals_training/ACP000692i_150.0.jpg',
#  'animals_training/ACP000dthx_150.0.jpg',
#  'animals_training/ACP0002rqx_130.0.jpg',
#  'animals_training/ACP000bi4a_100.0.jpg',
#  'animals_training/ACP000dl9u_20.0.jpg',
#  'animals_training/ACP000cgfh_30.0.jpg',
#  'animals_training/ACP000bfqq_190.0.jpg',
#  'animals_training/ACP000d6y5_160.0.jpg',
#  'animals_training/ACP0002crh_0.0.jpg',
#  'animals_training/ACP000bunf_280.0.jpg',
#  'animals_training/ACP0003dsc_170.0.jpg',
#  'animals_training/ACP000da4f_310.0.jpg',
#  'animals_training/ACP000dlf2_160.0.jpg',
#  'animals_training/ACP000b277_60.0.jpg',
#  'animals_training/ACP000d6xx_260.0.jpg',
#  'animals_training/ACP000d6wp_310.0.jpg',
#  'animals_training/ACP00058bt_60.0.jpg',
#  'animals_training/ACP000dpmm_130.0.jpg',
#  'animals_training/ACP000drxl_220.0.jpg',
#  'animals_training/ACP000cgbu_120.0.jpg',
#  'animals_training/ACP000dmwg_310.0.jpg',
#  'animals_training/ACP000bibl_110.0.jpg',
#  'animals_training/ACP000drdz_210.0.jpg',
#  'animals_training/ACP00054mi_330.0.jpg',
#  'animals_training/ACP0004tfr_80.0.jpg',
#  'animals_training/ACP000djl0_130.0.jpg',
#  'animals_training/ACP000dlnj_300.0.jpg',
#  'animals_training/ACP000drlv_330.0.jpg',
#  'animals_training/ACP000dqsq_250.0.jpg',
#  'animals_training/ACP000d71k_340.0.jpg',
#  'animals_training/ACP000d0md_250.0.jpg',
#  'animals_training/ACP000dn36_150.0.jpg',
#  'animals_training/ACP000dtb5_10.0.jpg',
#  'animals_training/ACP000dhd3_210.0.jpg',
#  'animals_training/ACP000drf2_130.0.jpg',
#  'animals_training/ACP000bb7c_110.0.jpg',
#  'animals_training/ACP000bh1v_150.0.jpg',
#  'animals_training/ACP000djue_50.0.jpg',
#  'animals_training/ACP000dlbm_90.0.jpg',
#  'animals_training/ACP000djov_290.0.jpg',
#  'animals_training/ACP000drc8_30.0.jpg',
#  'animals_training/ACP000d6if_60.0.jpg',
#  'animals_training/ACP000bmvt_350.0.jpg',
#  'animals_training/ACP000cu11_150.0.jpg',
#  'animals_training/ACP000dsr1_60.0.jpg',
#  'animals_training/ACP000d3sl_110.0.jpg',
#  'animals_training/ACP000dvi3_110.0.jpg',
#  'animals_training/ACP000d3ti_260.0.jpg',
#  'animals_training/ACP000d3tj_310.0.jpg',
#  'animals_training/ACP000d0me_290.0.jpg',
#  'animals_training/ACP000dmu2_310.0.jpg',
#  'animals_training/ACP0002rqc_10.0.jpg',
#  'animals_training/ACP000ds7k_100.0.jpg',
#  'animals_training/ACP000d0o9_90.0.jpg',
#  'animals_training/ACP000fwip_260.0.jpg',
#  'animals_training/ACP0002crg_130.0.jpg',
#  'animals_training/ACP000ce8p_190.0.jpg',
#  'animals_training/ACP000ds3o_220.0.jpg',
#  'animals_training/ACP000bu1j_330.0.jpg',
#  'animals_training/ACP000d7uz_20.0.jpg',
#  'animals_training/ACP000d3sm_80.0.jpg',
#  'animals_training/ACP000cr5l_60.0.jpg',
#  'animals_training/ACP000d3kl_180.0.jpg',
#  'animals_training/ACP000d9e3_20.0.jpg',
#  'animals_training/ACP000d3kh_190.0.jpg',
#  'animals_training/ACP000do4d_30.0.jpg',
#  'animals_training/ACP000fdsl_40.0.jpg',
#  'animals_training/ACP000drbh_130.0.jpg',
#  'animals_training/ACP000dtja_30.0.jpg',
#  'animals_training/ACP000cqs9_190.0.jpg',
#  'animals_training/ACP000bu1s_70.0.jpg',
#  'animals_training/ACP00025yv_170.0.jpg',
#  'animals_training/ACP000dsay_220.0.jpg',
#  'animals_training/ACP000doe8_130.0.jpg',
#  'animals_training/ACP000bb5h_150.0.jpg',
#  'animals_training/ACP000dsax_0.0.jpg',
#  'animals_training/ACP000djgr_100.0.jpg',
#  'animals_training/ACP000dojt_80.0.jpg',
#  'animals_training/ACP000dcj1_330.0.jpg',
#  'animals_training/ACP000du1n_70.0.jpg',
#  'animals_training/ACP000ds3a_40.0.jpg',
#  'animals_training/ACP0002p1n_20.0.jpg',
#  'animals_training/ACP000bt0h_290.0.jpg',
#  'animals_training/ACP000bi12_260.0.jpg',
#  'animals_training/ACP000b2n1_120.0.jpg',
#  'animals_training/ACP000d6wv_60.0.jpg',
#  'animals_training/ACP000587k_350.0.jpg',
#  'animals_training/ACP00021zs_160.0.jpg',
#  'animals_training/ACP000d6gm_260.0.jpg',
#  'animals_training/ACP000bv2p_80.0.jpg',
#  'animals_training/ACP000dpp8_130.0.jpg',
#  'animals_training/ACP0000973_60.0.jpg',
#  'animals_training/ACP00000ga_0.0.jpg',
#  'animals_training/ACP000ds38_220.0.jpg',
#  'animals_training/ACP000d6y9_200.0.jpg',
#  'animals_training/ACP000dm03_310.0.jpg',
#  'animals_training/ACP000do49_70.0.jpg',
#  'animals_training/ACP000d6hz_160.0.jpg',
#  'animals_training/ACP00029nq_240.0.jpg',
#  'animals_training/ACP000bgst_200.0.jpg',
#  'animals_training/ACP000d5u4_170.0.jpg',
#  'animals_training/ACP000dl9q_250.0.jpg',
#  'animals_training/ACP000cr85_120.0.jpg',
#  'animals_training/ACP000dn0m_80.0.jpg',
#  'animals_training/ACP000cin3_120.0.jpg',
#  'animals_training/ACP000d6wj_10.0.jpg',
#  'animals_training/ACP000djrt_100.0.jpg',
#  'animals_training/ACP000drdv_180.0.jpg',
#  'animals_training/ACP000dsx9_190.0.jpg',
#  'animals_training/ACP000d2kk_150.0.jpg',
#  'animals_training/ACP000cuxe_130.0.jpg',
#  'animals_training/ACP000duwl_150.0.jpg',
#  'animals_training/ACP0005jqz_60.0.jpg',
#  'animals_training/ACP000dsbr_100.0.jpg',
#  'animals_training/ACP000d01w_270.0.jpg',
#  'animals_training/ACP000djso_340.0.jpg',
#  'animals_training/ACP000ds7d_80.0.jpg',
#  'animals_training/ACP000djqm_190.0.jpg',
#  'animals_training/ACP000dsf7_40.0.jpg',
#  'animals_training/ACP000drx0_10.0.jpg',
#  'animals_training/ACP000dssm_190.0.jpg',
#  'animals_training/ACP000djzm_20.0.jpg',
#  'animals_training/ACP0002wci_240.0.jpg',
#  'animals_training/ACP000bgc0_320.0.jpg',
#  'animals_training/ACP000d3pq_270.0.jpg',
#  'animals_training/ACP000533i_10.0.jpg',
#  'animals_training/ACP00044gc_90.0.jpg',
#  'animals_training/ACP000d6rx_20.0.jpg',
#  'animals_training/ACP000cw64_250.0.jpg',
#  'animals_training/ACP000dtoa_340.0.jpg',
#  'animals_training/ACP000cd2x_240.0.jpg',
#  'animals_training/ACP000cggb_250.0.jpg',
#  'animals_training/ACP000bib2_180.0.jpg',
#  'animals_training/ACP0000217_130.0.jpg',
#  'animals_training/ACP000cghi_230.0.jpg',
#  'animals_training/ACP000dlex_320.0.jpg',
#  'animals_training/ACP000cg5o_80.0.jpg',
#  'animals_training/ACP000d70a_0.0.jpg',
#  'animals_training/ACP000dsn5_150.0.jpg',
#  'animals_training/ACP000dngo_220.0.jpg',
#  'animals_training/ACP000d6wp_250.0.jpg',
#  'animals_training/ACP000bhrl_210.0.jpg',
#  'animals_training/ACP000do4n_320.0.jpg',
#  'animals_training/ACP000c44i_250.0.jpg',
#  'animals_training/ACP000cg5p_70.0.jpg',
#  'animals_training/ACP000drf9_140.0.jpg',
#  'animals_training/ACP000dr4e_260.0.jpg',
#  'animals_training/ACP000dd8q_200.0.jpg',
#  'animals_training/ACP000c541_100.0.jpg',
#  'animals_training/ACP0003zvd_140.0.jpg',
#  'animals_training/ACP000d70v_320.0.jpg',
#  'animals_training/ACP000cw4s_120.0.jpg',
#  'animals_training/ACP000dmqt_90.0.jpg',
#  'animals_training/ACP000cew4_40.0.jpg',
#  'animals_training/ACP000bej3_10.0.jpg',
#  'animals_training/ACP000djja_230.0.jpg',
#  'animals_training/ACP000dlv8_240.0.jpg',
#  'animals_training/ACP000d0gp_20.0.jpg',
#  'animals_training/ACP000awpl_200.0.jpg',
#  'animals_training/ACP000do6i_190.0.jpg',
#  'animals_training/ACP000dsr3_320.0.jpg',
#  'animals_training/ACP000cz1p_90.0.jpg',
#  'animals_training/ACP000ds0m_0.0.jpg',
#  'animals_training/ACP000d6sx_240.0.jpg',
#  'animals_training/ACP000dmzq_250.0.jpg',
#  'animals_training/ACP000cgdb_340.0.jpg',
#  'animals_training/ACP000cggf_230.0.jpg',
#  'animals_training/ACP000djo5_280.0.jpg',
#  'animals_training/ACP000d0dz_240.0.jpg',
#  'animals_training/ACP000d7xy_70.0.jpg',
#  'animals_training/ACP000d6wm_190.0.jpg',
#  'animals_training/ACP0006lgr_70.0.jpg',
#  'animals_training/ACP000dsle_130.0.jpg',
#  'animals_training/ACP000dtuf_10.0.jpg',
#  'animals_training/ACP000ce3e_140.0.jpg',
#  'animals_training/ACP00074af_280.0.jpg',
#  'animals_training/ACP000dt3l_350.0.jpg',
#  'animals_training/ACP000dtng_280.0.jpg',
#  'animals_training/ACP000cvwo_320.0.jpg',
#  'animals_training/ACP000dtjd_130.0.jpg',
#  'animals_training/ACP000dsb2_110.0.jpg',
#  'animals_training/ACP000bxn1_180.0.jpg',
#  'animals_training/ACP000d68n_210.0.jpg',
#  'animals_training/ACP000drx6_320.0.jpg',
#  'animals_training/ACP000ds1h_280.0.jpg',
#  'animals_training/ACP000d6x6_350.0.jpg',
#  'animals_training/ACP000d6l3_70.0.jpg',
#  'animals_training/ACP000dk09_330.0.jpg',
#  'animals_training/ACP000d7l0_0.0.jpg',
#  'animals_training/ACP000dlno_170.0.jpg',
#  'animals_training/ACP000drw8_250.0.jpg',
#  'animals_training/ACP000do5o_30.0.jpg',
#  'animals_training/ACP000bv06_0.0.jpg',
#  'animals_training/ACP000dm7w_100.0.jpg',
#  'animals_training/ACP000bi4f_180.0.jpg',
#  'animals_training/ACP000d9au_210.0.jpg',
#  'animals_training/ACP000dobk_350.0.jpg',
#  'animals_training/ACP000da48_300.0.jpg',
#  'animals_training/ACP000dmvb_0.0.jpg',
#  'animals_training/ACP000bmeo_30.0.jpg',
#  'animals_training/ACP000bt7s_80.0.jpg',
#  'animals_training/ACP000d3ti_330.0.jpg',
#  'animals_training/ACP000djoa_170.0.jpg',
#  'animals_training/ACP000b3bx_180.0.jpg',
#  'animals_training/ACP000d3np_130.0.jpg',
#  'animals_training/ACP000dl9s_90.0.jpg',
#  'animals_training/ACP000dcfr_130.0.jpg',
#  'animals_training/ACP000d66p_220.0.jpg',
#  'animals_training/ACP000cygp_30.0.jpg',
#  'animals_training/ACP000bj70_30.0.jpg',
#  'animals_training/ACP000cdlu_160.0.jpg',
#  'animals_training/ACP0005w5g_220.0.jpg',
#  'animals_training/ACP000bnk4_330.0.jpg',
#  'animals_training/ACP000bsyy_50.0.jpg',
#  'animals_training/ACP000doll_40.0.jpg',
#  'animals_training/ACP000dsg9_140.0.jpg',
#  'animals_training/ACP000dts4_100.0.jpg',
#  'animals_training/ACP0002wcl_220.0.jpg',
#  'animals_training/ACP000dojt_290.0.jpg',
#  'animals_training/ACP000d6wt_120.0.jpg',
#  'animals_training/ACP00058ws_300.0.jpg',
#  'animals_training/ACP000dmb2_120.0.jpg',
#  'animals_training/ACP000dkud_260.0.jpg',
#  'animals_training/ACP000djr7_290.0.jpg',
#  'animals_training/ACP000bszl_290.0.jpg',
#  'animals_training/ACP000dl26_220.0.jpg',
#  'animals_training/ACP00027m0_340.0.jpg',
#  'animals_training/ACP000dpy5_120.0.jpg',
#  'animals_training/ACP000d0ot_30.0.jpg',
#  'animals_training/ACP000dsh3_320.0.jpg',
#  'animals_training/ACP000bn38_290.0.jpg',
#  'animals_training/ACP000cfl2_260.0.jpg',
#  'animals_training/ACP000bfpk_110.0.jpg',
#  'animals_training/ACP0003d97_60.0.jpg',
#  'animals_training/ACP000dlv4_130.0.jpg',
#  'animals_training/ACP000cgdb_180.0.jpg',
#  'animals_training/ACP000dr21_310.0.jpg',
#  'animals_training/ACP000bszm_320.0.jpg',
#  'animals_training/ACP000dmsq_200.0.jpg',
#  'animals_training/ACP000d6wt_260.0.jpg',
#  'animals_training/ACP000ccm2_60.0.jpg',
#  'animals_training/ACP0002p13_260.0.jpg',
#  'animals_training/ACP000cuxg_300.0.jpg',
#  'animals_training/ACP000cvz2_40.0.jpg',
#  'animals_training/ACP000doe6_130.0.jpg',
#  'animals_training/ACP000djjb_200.0.jpg',
#  'animals_training/ACP000drmy_30.0.jpg',
#  'animals_training/ACP000drb5_120.0.jpg',
#  'animals_training/ACP000bu4m_120.0.jpg',
#  'animals_training/ACP000dsye_310.0.jpg',
#  'animals_training/ACP000082d_350.0.jpg',
#  'animals_training/ACP000d5re_240.0.jpg',
#  'animals_training/ACP000flzk_160.0.jpg',
#  'animals_training/ACP000082d_210.0.jpg',
#  'animals_training/ACP000d5my_240.0.jpg',
#  'animals_training/ACP00022ho_290.0.jpg',
#  'animals_training/ACP000d71j_220.0.jpg',
#  'animals_training/ACP000dt6w_150.0.jpg',
#  'animals_training/ACP000bi67_300.0.jpg',
#  'animals_training/ACP000cgbv_320.0.jpg',
#  'animals_training/ACP00050c2_270.0.jpg',
#  'animals_training/ACP000d7lc_350.0.jpg',
#  'animals_training/ACP000da9x_210.0.jpg',
#  'animals_training/ACP0002938_30.0.jpg',
#  'animals_training/ACP000dm02_110.0.jpg',
#  'animals_training/ACP000dsuj_240.0.jpg',
#  'animals_training/ACP000dtcq_260.0.jpg',
#  'animals_training/ACP000drwd_110.0.jpg',
#  'animals_training/ACP000cux8_290.0.jpg',
#  'animals_training/ACP000do4b_170.0.jpg',
#  'animals_training/ACP000dl2w_330.0.jpg',
#  'animals_training/ACP000cuy8_210.0.jpg',
#  'animals_training/ACP000dsmy_110.0.jpg',
#  'animals_training/ACP000dl7j_40.0.jpg',
#  'animals_training/ACP000dmnx_180.0.jpg',
#  'animals_training/ACP000dfje_60.0.jpg',
#  'animals_training/ACP000dlym_300.0.jpg',
#  'animals_training/ACP000cmth_200.0.jpg',
#  'animals_training/ACP000bd1q_210.0.jpg',
#  'animals_training/ACP000224h_170.0.jpg',
#  'animals_training/ACP000bu1g_60.0.jpg',
#  'animals_training/ACP000cqzv_330.0.jpg',
#  'animals_training/ACP000dt6z_330.0.jpg',
#  'animals_training/ACP000d3n6_50.0.jpg',
#  'animals_training/ACP000che6_280.0.jpg',
#  'animals_training/ACP000dpi1_130.0.jpg',
#  'animals_training/ACP000dcj1_180.0.jpg',
#  'animals_training/ACP000dkqr_350.0.jpg',
#  'animals_training/ACP000do4k_180.0.jpg',
#  'animals_training/ACP000dn9w_90.0.jpg',
#  'animals_training/ACP000dabj_90.0.jpg',
#  'animals_training/ACP000c4cp_270.0.jpg',
#  'animals_training/ACP000d0bt_110.0.jpg',
#  'animals_training/ACP000do3u_90.0.jpg',
#  'animals_training/ACP000f0h8_320.0.jpg',
#  'animals_training/ACP000bgbx_280.0.jpg',
#  'animals_training/ACP000d9r6_30.0.jpg',
#  'animals_training/ACP000d3pu_10.0.jpg',
#  'animals_training/ACP000drn5_240.0.jpg',
#  'animals_training/ACP000cuxc_300.0.jpg',
#  'animals_training/ACP000d70r_40.0.jpg',
#  'animals_training/ACP000d9e7_80.0.jpg',
#  'animals_training/ACP000beib_90.0.jpg',
#  'animals_training/ACP000ce9o_60.0.jpg',
#  'animals_training/ACP000cvwp_170.0.jpg',
#  'animals_training/ACP000djnr_20.0.jpg',
#  'animals_training/ACP000d5ri_340.0.jpg',
#  'animals_training/ACP000e3xn_230.0.jpg',
#  'animals_training/ACP000dstn_270.0.jpg',
#  'animals_training/ACP000dnjb_230.0.jpg',
#  'animals_training/ACP000d0kl_290.0.jpg',
#  'animals_training/ACP000d9ih_150.0.jpg',
#  'animals_training/ACP000d3n2_210.0.jpg',
#  'animals_training/ACP000dsk1_0.0.jpg',
#  'animals_training/ACP000dci4_20.0.jpg',
#  'animals_training/ACP000esic_120.0.jpg',
#  'animals_training/ACP000bfp5_190.0.jpg',
#  'animals_training/ACP000djjb_100.0.jpg',
#  'animals_training/ACP000drii_50.0.jpg',
#  'animals_training/ACP000dqzp_130.0.jpg',
#  'animals_training/ACP000d3pj_20.0.jpg',
#  'animals_training/ACP000dkso_230.0.jpg',
#  'animals_training/ACP000dd8x_130.0.jpg',
#  'animals_training/ACP000d0o2_240.0.jpg',
#  'animals_training/ACP000dsro_40.0.jpg',
#  'animals_training/ACP000ds2m_10.0.jpg',
#  'animals_training/ACP00025lx_340.0.jpg',
#  'animals_training/ACP000bicm_100.0.jpg',
#  'animals_training/ACP000byah_180.0.jpg',
#  'animals_training/ACP000cn75_110.0.jpg',
#  'animals_training/ACP000d9h0_320.0.jpg',
#  'animals_training/ACP0000967_120.0.jpg',
#  'animals_training/ACP000bczm_310.0.jpg',
#  'animals_training/ACP000dlc1_190.0.jpg',
#  'animals_training/ACP000ctpt_200.0.jpg',
#  'animals_training/ACP000d57d_110.0.jpg',
#  'animals_training/ACP000dsil_160.0.jpg',
#  'animals_training/ACP000bd00_80.0.jpg',
#  'animals_training/ACP000dqzq_140.0.jpg',
#  'animals_training/ACP000dwj6_270.0.jpg',
#  'animals_training/ACP000dvec_330.0.jpg',
#  'animals_training/ACP000dsaj_90.0.jpg',
#  'animals_training/ACP000cggh_150.0.jpg',
#  'animals_training/ACP000g5cz_160.0.jpg',
#  'animals_training/ACP000dl9s_160.0.jpg',
#  'animals_training/ACP000dkgp_120.0.jpg',
#  'animals_training/ACP000djqo_230.0.jpg',
#  'animals_training/ACP000emir_310.0.jpg',
#  'animals_training/ACP000dlsm_230.0.jpg',
#  'animals_training/ACP000dnaf_20.0.jpg',
#  'animals_training/ACP000droj_180.0.jpg',
#  'animals_training/ACP000d7u0_60.0.jpg',
#  'animals_training/ACP000dnka_190.0.jpg',
#  'animals_training/ACP000dsyl_240.0.jpg',
#  'animals_training/ACP000dmyf_210.0.jpg',
#  'animals_training/ACP000bfqd_190.0.jpg',
#  'animals_training/ACP000d3pk_70.0.jpg',
#  'animals_training/ACP000dri7_40.0.jpg',
#  'animals_training/ACP000co0f_10.0.jpg',
#  'animals_training/ACP00027g1_290.0.jpg',
#  'animals_training/ACP0005tte_80.0.jpg',
#  'animals_training/ACP000cg5w_240.0.jpg',
#  'animals_training/ACP0004507_20.0.jpg',
#  'animals_training/ACP000drle_0.0.jpg',
#  'animals_training/ACP000cggc_50.0.jpg',
#  'animals_training/ACP000dlp8_60.0.jpg',
#  'animals_training/ACP000g2tu_210.0.jpg',
#  'animals_training/ACP000dabr_40.0.jpg',
#  'animals_training/ACP000drx0_120.0.jpg',
#  'animals_training/ACP000dofx_350.0.jpg',
#  'animals_training/ACP000djso_270.0.jpg',
#  'animals_training/ACP0005uet_150.0.jpg',
#  'animals_training/ACP000ban4_120.0.jpg',
#  'animals_training/ACP000dlhn_260.0.jpg',
#  'animals_training/ACP000cg5n_310.0.jpg',
#  'animals_training/ACP000dsbt_270.0.jpg',
#  'animals_training/ACP000bekp_20.0.jpg',
#  'animals_training/ACP000dsbr_170.0.jpg',
#  'animals_training/ACP000dn9y_280.0.jpg',
#  'animals_training/ACP000dlr7_70.0.jpg',
#  'animals_training/ACP000bick_330.0.jpg',
#  'animals_training/ACP000bia9_230.0.jpg',
#  'animals_training/ACP000bijv_230.0.jpg',
#  'animals_training/ACP000dn26_340.0.jpg',
#  'animals_training/ACP000d8bu_50.0.jpg',
#  'animals_training/ACP000dd7b_40.0.jpg',
#  'animals_training/ACP000d6ct_90.0.jpg',
#  'animals_training/ACP000d6ds_20.0.jpg',
#  'animals_training/ACP000ceno_110.0.jpg',
#  'animals_training/ACP000d0gt_340.0.jpg',
#  'animals_training/ACP000bfp3_190.0.jpg',
#  'animals_training/ACP000czkb_170.0.jpg',
#  'animals_training/ACP0003doz_10.0.jpg',
#  'animals_training/ACP000dr1l_310.0.jpg',
#  'animals_training/ACP000dmzd_310.0.jpg',
#  'animals_training/ACP00058vx_50.0.jpg',
#  'animals_training/ACP000bfow_10.0.jpg',
#  'animals_training/ACP000d72x_350.0.jpg',
#  'animals_training/ACP000dmb5_350.0.jpg',
#  'animals_training/ACP000cqtq_70.0.jpg',
#  'animals_training/ACP000d0ne_150.0.jpg',
#  'animals_training/ACP000cz1q_350.0.jpg',
#  'animals_training/ACP000d3ne_70.0.jpg',
#  'animals_training/ACP000djzl_50.0.jpg',
#  'animals_training/ACP000bfpm_80.0.jpg',
#  'animals_training/ACP0004tfs_10.0.jpg',
#  'animals_training/ACP000cgdu_10.0.jpg',
#  'animals_training/ACP000drml_190.0.jpg',
#  'animals_training/ACP000dnk7_180.0.jpg',
#  'animals_training/ACP000e3y9_150.0.jpg',
#  'animals_training/ACP000dlsm_120.0.jpg',
#  'animals_training/ACP000dj6p_120.0.jpg',
#  'animals_training/ACP000b3c2_310.0.jpg',
#  'animals_training/ACP000cgbw_230.0.jpg',
#  'animals_training/ACP000082h_220.0.jpg',
#  'animals_training/ACP000cgf4_330.0.jpg',
#  'animals_training/ACP000bicv_340.0.jpg',
#  'animals_training/ACP000drxo_300.0.jpg',
#  'animals_training/ACP000dls6_320.0.jpg',
#  'animals_training/ACP0002ud1_150.0.jpg',
#  'animals_training/ACP000djy4_20.0.jpg',
#  'animals_training/ACP000dto4_70.0.jpg',
#  'animals_training/ACP000dojs_340.0.jpg',
#  'animals_training/ACP000d0nh_70.0.jpg',
#  'animals_training/ACP000dsn2_10.0.jpg',
#  'animals_training/ACP000dl42_80.0.jpg',
#  'animals_training/ACP0002cw3_270.0.jpg',
#  'animals_training/ACP000dcgg_60.0.jpg',
#  'animals_training/ACP0003bi9_60.0.jpg',
#  'animals_training/ACP000dkzj_250.0.jpg',
#  'animals_training/ACP000dski_10.0.jpg',
#  'animals_training/ACP000d6or_330.0.jpg',
#  'animals_training/ACP000do9r_270.0.jpg',
#  'animals_training/ACP000dt81_40.0.jpg',
#  'animals_training/ACP000d61f_80.0.jpg',
#  'animals_training/ACP000drx0_180.0.jpg',
#  'animals_training/ACP000btba_320.0.jpg',
#  'animals_training/ACP000d0en_20.0.jpg',
#  'animals_training/ACP0004foq_20.0.jpg',
#  'animals_training/ACP000dlbr_90.0.jpg',
#  'animals_training/ACP000dj6p_190.0.jpg',
#  'animals_training/ACP000dtob_140.0.jpg',
#  'animals_training/ACP000fttq_290.0.jpg',
#  'animals_training/ACP000cuf4_300.0.jpg',
#  'animals_training/ACP000cgcq_10.0.jpg',
#  'animals_training/ACP000dryn_40.0.jpg',
#  'animals_training/ACP000dnb9_340.0.jpg',
#  'animals_training/ACP000d0o2_230.0.jpg',
#  'animals_training/ACP000cvif_110.0.jpg',
#  'animals_training/ACP000dsz8_90.0.jpg',
#  'animals_training/ACP000bibl_180.0.jpg',
#  'animals_training/ACP000cn73_330.0.jpg',
#  'animals_training/ACP000d6wh_70.0.jpg',
#  'animals_training/ACP000d0km_140.0.jpg',
#  'animals_training/ACP00025yt_250.0.jpg',
#  'animals_training/ACP000dsc1_120.0.jpg',
#  'animals_training/ACP00001vq_50.0.jpg',
#  'animals_training/ACP000d674_350.0.jpg',
#  'animals_training/ACP000dt71_300.0.jpg',
#  'animals_training/ACP000drdy_40.0.jpg',
#  'animals_training/ACP000cnyo_0.0.jpg',
#  'animals_training/ACP000cbhu_30.0.jpg',
#  'animals_training/ACP000djn7_130.0.jpg',
#  'animals_training/ACP000dljy_210.0.jpg',
#  'animals_training/ACP000cqtu_200.0.jpg',
#  'animals_training/ACP000dl63_40.0.jpg',
#  'animals_training/ACP000d6y2_350.0.jpg',
#  'animals_training/ACP000dmzr_0.0.jpg',
#  'animals_training/ACP000dkry_140.0.jpg',
#  'animals_training/ACP000d9we_220.0.jpg',
#  'animals_training/ACP000ds74_110.0.jpg',
#  'animals_training/ACP000drjl_190.0.jpg',
#  'animals_training/ACP00054mi_120.0.jpg',
#  'animals_training/ACP000d9f5_260.0.jpg',
#  'animals_training/ACP000don0_150.0.jpg',
#  'animals_training/ACP000dkux_120.0.jpg',
#  'animals_training/ACP000cz1o_50.0.jpg',
#  'animals_training/ACP000293c_150.0.jpg',
#  'animals_training/ACP000czzn_230.0.jpg',
#  'animals_training/ACP00001wd_20.0.jpg',
#  'animals_training/ACP000d3pl_200.0.jpg',
#  'animals_training/ACP000do6f_250.0.jpg',
#  'animals_training/ACP000082c_10.0.jpg',
#  'animals_training/ACP000dkqp_30.0.jpg',
#  'animals_training/ACP000dobi_310.0.jpg',
#  'animals_training/ACP000drbw_250.0.jpg',
#  'animals_training/ACP000dlsl_110.0.jpg',
#  'animals_training/ACP00044h9_30.0.jpg',
#  'animals_training/ACP000bicu_350.0.jpg',
#  'animals_training/ACP000by87_320.0.jpg',
#  'animals_training/ACP0002cpi_40.0.jpg',
#  'animals_training/ACP000d3nh_170.0.jpg',
#  'animals_training/ACP000dk4d_160.0.jpg',
#  'animals_training/ACP000beia_300.0.jpg',
#  'animals_training/ACP000drab_150.0.jpg',
#  'animals_training/ACP000d4rn_0.0.jpg',
#  'animals_training/ACP000djpt_180.0.jpg',
#  'animals_training/ACP000dlv5_250.0.jpg',
#  'animals_training/ACP000dcju_170.0.jpg',
#  'animals_training/ACP000293k_30.0.jpg',
#  'animals_training/ACP000dff6_190.0.jpg',
#  'animals_training/ACP000cg7x_240.0.jpg',
#  'animals_training/ACP0000218_340.0.jpg',
#  'animals_training/ACP000092m_90.0.jpg',
#  'animals_training/ACP000cenw_50.0.jpg',
#  'animals_training/ACP000d6wq_350.0.jpg',
#  'animals_training/ACP000emju_10.0.jpg',
#  'animals_training/ACP000djmf_250.0.jpg',
#  'animals_training/ACP000cgga_210.0.jpg',
#  'animals_training/ACP000d3nn_90.0.jpg',
#  'animals_training/ACP000drce_60.0.jpg',
#  'animals_training/ACP0004tfd_230.0.jpg',
#  'animals_training/ACP000cd1l_320.0.jpg',
#  'animals_training/ACP000flzj_70.0.jpg',
#  'animals_training/ACP000djvu_180.0.jpg',
#  'animals_training/ACP000d5n0_180.0.jpg',
#  'animals_training/ACP000beo5_110.0.jpg',
#  'animals_training/ACP000d01v_70.0.jpg',
#  'animals_training/ACP000cz1o_210.0.jpg',
#  'animals_training/ACP000byac_200.0.jpg',
#  'animals_training/ACP000dlrp_120.0.jpg',
#  'animals_training/ACP000225z_130.0.jpg',
#  'animals_training/ACP000dsga_260.0.jpg',
#  'animals_training/ACP000dr1e_230.0.jpg',
#  'animals_training/ACP000dodf_250.0.jpg',
#  'animals_training/ACP000cr8r_70.0.jpg',
#  'animals_training/ACP000drws_240.0.jpg',
#  'animals_training/ACP000do5q_180.0.jpg',
#  'animals_training/ACP000dslc_290.0.jpg',
#  'animals_training/ACP000d7uz_150.0.jpg',
#  'animals_training/ACP000dkzg_100.0.jpg',
#  'animals_training/ACP000dsdg_80.0.jpg',
#  'animals_training/ACP000dsx9_230.0.jpg',
#  'animals_training/ACP000d9ax_290.0.jpg',
#  'animals_training/ACP000czka_90.0.jpg',
#  'animals_training/ACP000cgds_110.0.jpg',
#  'animals_training/ACP000djoa_180.0.jpg',
#  'animals_training/ACP000cy9l_170.0.jpg',
#  'animals_training/ACP000d6hm_50.0.jpg',
#  'animals_training/ACP000dsh8_220.0.jpg',
#  'animals_training/ACP0002ra2_110.0.jpg',
#  'animals_training/ACP0007p0m_240.0.jpg',
#  'animals_training/ACP000cz3v_280.0.jpg',
#  'animals_training/ACP000d0fe_60.0.jpg',
#  'animals_training/ACP000bxjp_10.0.jpg',
#  'animals_training/ACP0005650_160.0.jpg',
#  'animals_training/ACP000do47_70.0.jpg',
#  'animals_training/ACP000eduz_30.0.jpg',
#  'animals_training/ACP0002ja6_290.0.jpg',
#  'animals_training/ACP000dreq_160.0.jpg',
#  'animals_training/ACP000do4n_30.0.jpg',
#  'animals_training/ACP000b3no_310.0.jpg',
#  'animals_training/ACP000drm2_0.0.jpg',
#  'animals_training/ACP000dsw7_80.0.jpg',
#  'animals_training/ACP000d6xo_330.0.jpg',
#  'animals_training/ACP000dmfo_120.0.jpg',
#  'animals_training/ACP000d0ni_140.0.jpg',
#  'animals_training/ACP000dofw_120.0.jpg',
#  'animals_training/ACP000dlv8_120.0.jpg',
#  'animals_training/ACP000bt7q_220.0.jpg',
#  'animals_training/ACP000d9v1_30.0.jpg',
#  'animals_training/ACP000bibl_170.0.jpg',
#  'animals_training/ACP000d6xn_240.0.jpg',
#  'animals_training/ACP000drrx_80.0.jpg',
#  'animals_training/ACP000drbc_200.0.jpg',
#  'animals_training/ACP000dvjg_170.0.jpg',
#  'animals_training/ACP000doe6_90.0.jpg',
#  'animals_training/ACP000drws_70.0.jpg',
#  'animals_training/ACP000bekm_270.0.jpg',
#  'animals_training/ACP00027zp_150.0.jpg',
#  'animals_training/ACP000djn8_160.0.jpg',
#  'animals_training/ACP000d3mx_250.0.jpg',
#  'animals_training/ACP000cqzr_210.0.jpg',
#  'animals_training/ACP000d6p1_130.0.jpg',
#  'animals_training/ACP000bszl_170.0.jpg',
#  'animals_training/ACP000cgbx_310.0.jpg',
#  'animals_training/ACP0006ro1_50.0.jpg',
#  'animals_training/ACP000djj5_0.0.jpg',
#  'animals_training/ACP000dmy3_260.0.jpg',
#  'animals_training/ACP000dwmc_350.0.jpg',
#  'animals_training/ACP000dp6p_190.0.jpg',
#  'animals_training/ACP000d73e_270.0.jpg',
#  'animals_training/ACP000bu80_260.0.jpg',
#  'animals_training/ACP0003dwe_70.0.jpg',
#  'animals_training/ACP000dpjq_230.0.jpg',
#  'animals_training/ACP000d6qf_130.0.jpg',
#  'animals_training/ACP000dm04_10.0.jpg',
#  'animals_training/ACP00029ds_260.0.jpg',
#  'animals_training/ACP000bics_260.0.jpg',
#  'animals_training/ACP000bt4l_110.0.jpg',
#  'animals_training/ACP000bib2_240.0.jpg',
#  'animals_training/ACP000dpiv_310.0.jpg',
#  'animals_training/ACP000cr86_260.0.jpg',
#  'animals_training/ACP000dpfp_130.0.jpg',
#  'animals_training/ACP000cghi_160.0.jpg',
#  'animals_training/ACP000d3pj_60.0.jpg',
#  'animals_training/ACP000d9b3_40.0.jpg',
#  'animals_training/ACP000bxnf_40.0.jpg',
#  'animals_training/ACP000dlr7_230.0.jpg',
#  'animals_training/ACP000dssj_70.0.jpg',
#  'animals_training/ACP00027m8_350.0.jpg',
#  'animals_training/ACP000dqsu_130.0.jpg',
#  'animals_training/ACP000dtt3_150.0.jpg',
#  'animals_training/ACP000cvwr_120.0.jpg',
#  'animals_training/ACP000djq2_50.0.jpg',
#  'animals_training/ACP0006ur1_350.0.jpg',
#  'animals_training/ACP000d3pl_260.0.jpg',
#  'animals_training/ACP00028y8_20.0.jpg',
#  'animals_training/ACP000bybe_330.0.jpg',
#  'animals_training/ACP000dsr5_290.0.jpg',
#  'animals_training/ACP000do6i_60.0.jpg',
#  'animals_training/ACP000crak_230.0.jpg',
#  'animals_training/ACP000dr21_230.0.jpg',
#  'animals_training/ACP000bicv_110.0.jpg',
#  'animals_training/ACP0003dor_310.0.jpg',
#  'animals_training/ACP000dlhn_270.0.jpg',
#  'animals_training/ACP000do6i_10.0.jpg',
#  'animals_training/ACP000do6j_80.0.jpg',
#  'animals_training/ACP000czm7_30.0.jpg',
#  'animals_training/ACP000dlsz_190.0.jpg',
#  'animals_training/ACP000dt0z_200.0.jpg',
#  'animals_training/ACP000d0jd_60.0.jpg',
#  'animals_training/ACP000dmrz_270.0.jpg',
#  'animals_training/ACP000bt04_210.0.jpg',
#  'animals_training/ACP000dmwh_250.0.jpg',
#  'animals_training/ACP000d73g_30.0.jpg',
#  'animals_training/ACP000dvd0_280.0.jpg',
#  'animals_training/ACP000dphb_0.0.jpg',
#  'animals_training/ACP000b65p_340.0.jpg',
#  'animals_training/ACP000dktv_300.0.jpg',
#  'animals_training/ACP000dfeb_350.0.jpg',
#  'animals_training/ACP000dmzb_210.0.jpg',
#  'animals_training/ACP000dobj_300.0.jpg',
#  'animals_training/ACP000dltf_20.0.jpg',
#  'animals_training/ACP000dpha_0.0.jpg',
#  'animals_training/ACP000doju_180.0.jpg',
#  'animals_training/ACP00001vl_250.0.jpg',
#  'animals_training/ACP0004v1t_270.0.jpg',
#  'animals_training/ACP000d9ui_250.0.jpg',
#  'animals_training/ACP000do47_320.0.jpg',
#  'animals_training/ACP000dlro_120.0.jpg',
#  'animals_training/ACP000cc0u_260.0.jpg',
#  'animals_training/ACP000d3nj_260.0.jpg',
#  'animals_training/ACP000dmlz_160.0.jpg',
#  'animals_training/ACP0002t02_50.0.jpg',
#  'animals_training/ACP000dr5t_320.0.jpg',
#  'animals_training/ACP000czs5_60.0.jpg',
#  'animals_training/ACP0005jwm_230.0.jpg',
#  'animals_training/ACP000bv86_340.0.jpg',
#  'animals_training/ACP000cggh_140.0.jpg',
#  'animals_training/ACP000dphw_30.0.jpg',
#  'animals_training/ACP000d0df_240.0.jpg',
#  'animals_training/ACP000b3dn_230.0.jpg',
#  'animals_training/ACP000dk0j_170.0.jpg',
#  'animals_training/ACP000cz1o_100.0.jpg',
#  'animals_training/ACP000baee_30.0.jpg',
#  'animals_training/ACP0006tdk_140.0.jpg',
#  'animals_training/ACP000ce9q_0.0.jpg',
#  'animals_training/ACP000drve_70.0.jpg',
#  'animals_training/ACP00071r0_190.0.jpg',
#  'animals_training/ACP000exqm_330.0.jpg',
#  'animals_training/ACP000bfp7_140.0.jpg',
#  'animals_training/ACP000cvz4_260.0.jpg',
#  'animals_training/ACP000dmlp_130.0.jpg',
#  'animals_training/ACP0006vaq_60.0.jpg',
#  'animals_training/ACP000d6wc_60.0.jpg',
#  'animals_training/ACP000d0ni_150.0.jpg',
#  'animals_training/ACP000cgbw_190.0.jpg',
#  'animals_training/ACP0002ja7_310.0.jpg',
#  'animals_training/ACP000dpis_350.0.jpg',
#  'animals_training/ACP000d0nj_250.0.jpg',
#  'animals_training/ACP000d0dx_290.0.jpg',
#  'animals_training/ACP000d4sx_330.0.jpg',
#  'animals_training/ACP000cg8q_70.0.jpg',
#  'animals_training/ACP000dnka_300.0.jpg',
#  'animals_training/ACP00027gw_290.0.jpg',
#  'animals_training/ACP000cgf6_260.0.jpg',
#  'animals_training/ACP000cmti_160.0.jpg',
#  'animals_training/ACP0003d97_100.0.jpg',
#  'animals_training/ACP000dhfv_240.0.jpg',
#  'animals_training/ACP000dk08_130.0.jpg',
#  'animals_training/ACP000dn9f_0.0.jpg',
#  'animals_training/ACP000cnpu_310.0.jpg',
#  'animals_training/ACP000dpmm_340.0.jpg',
#  'animals_training/ACP000dror_200.0.jpg',
#  'animals_training/ACP000bfpe_30.0.jpg',
#  'animals_training/ACP000cgi8_210.0.jpg',
#  'animals_training/ACP0003dx0_110.0.jpg',
#  'animals_training/ACP000dsqd_240.0.jpg',
#  'animals_training/ACP000cn77_80.0.jpg',
#  'animals_training/ACP000d0w6_270.0.jpg',
#  'animals_training/ACP000cg74_320.0.jpg',
#  'animals_training/ACP000djl4_200.0.jpg',
#  'animals_training/ACP0002crg_100.0.jpg',
#  'animals_training/ACP000c6ly_320.0.jpg',
#  'animals_training/ACP000dd8k_340.0.jpg',
#  'animals_training/ACP000d9cy_160.0.jpg',
#  'animals_training/ACP000bmvt_200.0.jpg',
#  'animals_training/ACP000dogn_320.0.jpg',
#  'animals_training/ACP000d697_150.0.jpg',
#  'animals_training/ACP0002cpb_340.0.jpg',
#  'animals_training/ACP000d0s1_340.0.jpg',
#  'animals_training/ACP000bumd_260.0.jpg',
#  'animals_training/ACP000dmfs_150.0.jpg',
#  'animals_training/ACP000d0fl_110.0.jpg',
#  'animals_training/ACP000dmzk_220.0.jpg',
#  'animals_training/ACP000dpcf_100.0.jpg',
#  'animals_training/ACP000dtug_330.0.jpg',
#  'animals_training/ACP000ds6m_60.0.jpg',
#  'animals_training/ACP000dms0_340.0.jpg',
#  'animals_training/ACP000dn3v_150.0.jpg',
#  'animals_training/ACP000dmn5_310.0.jpg',
#  'animals_training/ACP000d0md_330.0.jpg',
#  'animals_training/ACP000bhwv_280.0.jpg',
#  'animals_training/ACP000czkc_0.0.jpg',
#  'animals_training/ACP000doj3_260.0.jpg',
#  'animals_training/ACP000dpjn_200.0.jpg',
#  'animals_training/ACP000d6wm_230.0.jpg',
#  'animals_training/ACP000bwvz_110.0.jpg',
#  'animals_training/ACP000020x_50.0.jpg',
#  'animals_training/ACP000cr8h_210.0.jpg',
#  'animals_training/ACP000do6p_170.0.jpg',
#  'animals_training/ACP000d73f_110.0.jpg',
#  'animals_training/ACP000dpiy_210.0.jpg',
#  'animals_training/ACP000d5nw_150.0.jpg',
#  'animals_training/ACP000dssi_60.0.jpg',
#  'animals_training/ACP0007g9q_90.0.jpg',
#  'animals_training/ACP000cvi9_290.0.jpg',
#  'animals_training/ACP000dku0_320.0.jpg',
#  'animals_training/ACP00036t8_240.0.jpg',
#  'animals_training/ACP000ce98_110.0.jpg',
#  'animals_training/ACP000dsdf_330.0.jpg',
#  'animals_training/ACP000czu0_140.0.jpg',
#  'animals_training/ACP000dmst_190.0.jpg',
#  'animals_training/ACP000d3ou_70.0.jpg',
#  'animals_training/ACP000dkxq_150.0.jpg',
#  'animals_training/ACP000dpix_80.0.jpg',
#  'animals_training/ACP00027kh_320.0.jpg',
#  'animals_training/ACP000drhq_320.0.jpg',
#  'animals_training/ACP0003t3o_250.0.jpg',
#  'animals_training/ACP000ce8o_130.0.jpg',
#  'animals_training/ACP000d71x_70.0.jpg',
#  'animals_training/ACP000cezp_330.0.jpg',
#  'animals_training/ACP000dvi3_260.0.jpg',
#  'animals_training/ACP000dsf7_120.0.jpg',
#  'animals_training/ACP0002251_340.0.jpg',
#  'animals_training/ACP00070nc_260.0.jpg',
#  'animals_training/ACP0005l7w_230.0.jpg',
#  'animals_training/ACP000dlqc_210.0.jpg',
#  'animals_training/ACP000297s_160.0.jpg',
#  'animals_training/ACP000dtnf_100.0.jpg',
#  'animals_training/ACP000dkhm_340.0.jpg',
#  'animals_training/ACP000bunf_0.0.jpg',
#  'animals_training/ACP000dcvy_210.0.jpg',
#  'animals_training/ACP000co3j_290.0.jpg',
#  'animals_training/ACP000dsw6_310.0.jpg',
#  'animals_training/ACP000bek4_10.0.jpg',
#  'animals_training/ACP000d0kc_170.0.jpg',
#  'animals_training/ACP000dfjk_60.0.jpg',
#  'animals_training/ACP0002l31_260.0.jpg',
#  'animals_training/ACP000dvd1_210.0.jpg',
#  'animals_training/ACP000cu10_70.0.jpg',
#  'animals_training/ACP000dlv4_40.0.jpg',
#  'animals_training/ACP00071r0_120.0.jpg',
#  'animals_training/ACP000d6wv_260.0.jpg',
#  'animals_training/ACP000cntr_180.0.jpg',
#  'animals_training/ACP000dtcq_230.0.jpg',
#  'animals_training/ACP000d3pk_0.0.jpg',
#  'animals_training/ACP00027ly_120.0.jpg',
#  'animals_training/ACP000dsiq_70.0.jpg',
#  'animals_training/ACP0000909_80.0.jpg',
#  'animals_training/ACP000cw92_0.0.jpg',
#  'animals_training/ACP000da8s_80.0.jpg',
#  'animals_training/ACP000bt4h_260.0.jpg',
#  'animals_training/ACP000dt71_160.0.jpg',
#  'animals_training/ACP0002crm_40.0.jpg',
#  'animals_training/ACP000d9wg_170.0.jpg',
#  'animals_training/ACP000ds6k_350.0.jpg',
#  'animals_training/ACP000d5u1_230.0.jpg',
#  'animals_training/ACP000ds38_120.0.jpg',
#  'animals_training/ACP000d0ov_30.0.jpg',
#  'animals_training/ACP000dsue_80.0.jpg',
#  'animals_training/ACP000bu1t_150.0.jpg',
#  'animals_training/ACP000b7bp_0.0.jpg',
#  'animals_training/ACP000d71c_330.0.jpg',
#  'animals_training/ACP000dr7a_210.0.jpg',
#  'animals_training/ACP000dmwk_240.0.jpg',
#  'animals_training/ACP000ds7k_180.0.jpg']
