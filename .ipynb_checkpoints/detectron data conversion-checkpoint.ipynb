# %%
import os
import numpy as np
import json
import csv
import pandas as pd
import random

# %%
# You may need to restart your runtime prior to this, to let your installation take effect
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import cv2
import random
# from google.colab.patches import cv2_imshow

# import some common detectron2 utilities
from detectron2.structures import BoxMode
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import DatasetCatalog, MetadataCatalog

# %%
def get_animals_dicts(img_dir):
        
    csv_file = os.path.join(img_dir, "2020-02-14.csv")
    imgs_anns = pd.read_csv(csv_file, sep= ",", header=0)
    classes = list(set(imgs_anns['species']))
    
    dataset_dicts = []

    imgs_anns = imgs_anns.sample(frac=1)
    files = list(set(imgs_anns['file']))
    random.shuffle(files)
    dataset_dicts = []
    
    idx = 0
    
    for file in files:
        data = imgs_anns[imgs_anns['file'] == file]

        record = {}

        record["file_name"] = file
        record["image_id"] = idx
        idx += 1
        record["height"] = int(data['height'][:1])
        record["width"] = int(data['width'][:1])


        objs = []
        for index, row in data.iterrows():
            obj = {
                "bbox": [int(row['x']), int(row['y']), int(row['w']), int(row['h'])],
                "bbox_mode": BoxMode.XYXY_ABS,
                "category_id": classes.index(row['species']),
                "iscrowd": 0
            }
            objs.append(obj)
        record["annotations"] = objs
        dataset_dicts.append(record)
    return dataset_dicts

# %%
for d in ["training", "val"]:
    DatasetCatalog.register("animals_" + d, lambda d=d: get_animals_dicts("animals_" + d + "/"))
    csv_file = os.path.join("animals_" + d, "2020-02-14.csv")
    imgs_anns = pd.read_csv(csv_file, sep= ",", header=0)
    classes = list(set(imgs_anns['species']))
    MetadataCatalog.get("animals_" + d).set(thing_classes=classes)
animal_metadata = MetadataCatalog.get("animals_training")

# %%
import random
from detectron2.utils.visualizer import Visualizer

dataset_dicts = get_animals_dicts('animals_training')

# %%
for d in random.sample(dataset_dicts, 50):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=animal_metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    cv2.imshow('', vis.get_image()[:, :, ::-1])
    cv2.waitKey(0) # waits until a key is pressed     
    cv2.destroyAllWindows() # destroys the window showing image

# %%
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("animals_training",)
cfg.DATASETS.TEST = ()
cfg.DATALOADER.NUM_WORKERS = 1
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x.yaml")  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 1
cfg.SOLVER.BASE_LR = 0.00001  # pick a good LR
cfg.SOLVER.MAX_ITER = 300000    # 300 iterations seems good enough for this toy dataset; you may need to train longer for a practical dataset
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 512   # faster, and good enough for this toy dataset (default: 512)
cfg.MODEL.ROI_HEADS.NUM_CLASSES = len(MetadataCatalog.get("animals_training").thing_classes)  # only has one class (ballon)
# cfg.MODEL.RPN.PRE_NMS_TOPK_TRAIN = 1000
# cfg.MODEL.RPN.POST_NMS_TOPK_TRAIN = 1000

# %%
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = DefaultTrainer(cfg) 
trainer.resume_or_load(resume=True)
# trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [02/27 08:44:00 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=18, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=68, bias=True)
#     )
#   )
# )
# [02/27 08:47:17 d2.data.build]: Removed 0 images with no usable annotations. 49859 images left.
# [02/27 08:47:18 d2.data.detection_utils]: TransformGens used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [02/27 08:47:18 d2.data.build]: Using training sampler TrainingSampler
# [02/27 08:47:19 d2.engine.train_loop]: Starting training from iteration 250000
# [02/27 08:47:28 d2.utils.events]: eta: 6:26:07  iter: 250019  total_loss: 0.102  loss_cls: 0.079  loss_box_reg: 0.029  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4701  data_time: 0.0051  lr: 0.000003  max_mem: 4055M
# [02/27 08:47:38 d2.utils.events]: eta: 6:30:29  iter: 250039  total_loss: 0.079  loss_cls: 0.025  loss_box_reg: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4744  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:47:47 d2.utils.events]: eta: 6:36:41  iter: 250059  total_loss: 0.133  loss_cls: 0.051  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4750  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:47:57 d2.utils.events]: eta: 6:41:58  iter: 250079  total_loss: 0.055  loss_cls: 0.031  loss_box_reg: 0.022  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4790  data_time: 0.0018  lr: 0.000003  max_mem: 4055M
# [02/27 08:48:07 d2.utils.events]: eta: 6:45:03  iter: 250099  total_loss: 0.080  loss_cls: 0.041  loss_box_reg: 0.033  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4812  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:48:16 d2.utils.events]: eta: 6:44:54  iter: 250119  total_loss: 0.079  loss_cls: 0.030  loss_box_reg: 0.036  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4823  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:48:27 d2.utils.events]: eta: 6:47:19  iter: 250139  total_loss: 0.084  loss_cls: 0.058  loss_box_reg: 0.028  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4852  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:48:36 d2.utils.events]: eta: 6:46:25  iter: 250159  total_loss: 0.062  loss_cls: 0.026  loss_box_reg: 0.029  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4858  data_time: 0.0018  lr: 0.000003  max_mem: 4055M
# [02/27 08:48:46 d2.utils.events]: eta: 6:44:53  iter: 250179  total_loss: 0.088  loss_cls: 0.067  loss_box_reg: 0.031  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4849  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:48:56 d2.utils.events]: eta: 6:46:05  iter: 250199  total_loss: 0.098  loss_cls: 0.055  loss_box_reg: 0.022  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4858  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:49:06 d2.utils.events]: eta: 6:48:16  iter: 250219  total_loss: 0.159  loss_cls: 0.090  loss_box_reg: 0.035  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4875  data_time: 0.0015  lr: 0.000003  max_mem: 4055M
# [02/27 08:49:16 d2.utils.events]: eta: 6:49:02  iter: 250239  total_loss: 0.119  loss_cls: 0.060  loss_box_reg: 0.024  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4882  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:49:26 d2.utils.events]: eta: 6:49:47  iter: 250259  total_loss: 0.201  loss_cls: 0.123  loss_box_reg: 0.037  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4901  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:49:36 d2.utils.events]: eta: 6:50:31  iter: 250279  total_loss: 0.141  loss_cls: 0.082  loss_box_reg: 0.040  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4911  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:49:47 d2.utils.events]: eta: 6:51:49  iter: 250299  total_loss: 0.078  loss_cls: 0.048  loss_box_reg: 0.029  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4933  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:49:57 d2.utils.events]: eta: 6:51:49  iter: 250319  total_loss: 0.089  loss_cls: 0.049  loss_box_reg: 0.035  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4943  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:50:07 d2.utils.events]: eta: 6:52:52  iter: 250339  total_loss: 0.079  loss_cls: 0.025  loss_box_reg: 0.034  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 0.4957  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:50:17 d2.utils.events]: eta: 6:52:28  iter: 250359  total_loss: 0.074  loss_cls: 0.041  loss_box_reg: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4956  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:50:28 d2.utils.events]: eta: 6:53:19  iter: 250379  total_loss: 0.089  loss_cls: 0.054  loss_box_reg: 0.038  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4968  data_time: 0.0018  lr: 0.000003  max_mem: 4055M
# [02/27 08:50:38 d2.utils.events]: eta: 6:53:19  iter: 250399  total_loss: 0.093  loss_cls: 0.043  loss_box_reg: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4975  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:50:48 d2.utils.events]: eta: 6:53:15  iter: 250419  total_loss: 0.059  loss_cls: 0.023  loss_box_reg: 0.028  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4976  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:50:58 d2.utils.events]: eta: 6:53:23  iter: 250439  total_loss: 0.060  loss_cls: 0.025  loss_box_reg: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4977  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:51:08 d2.utils.events]: eta: 6:53:38  iter: 250459  total_loss: 0.277  loss_cls: 0.168  loss_box_reg: 0.033  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4983  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:51:18 d2.utils.events]: eta: 6:53:32  iter: 250479  total_loss: 0.126  loss_cls: 0.058  loss_box_reg: 0.040  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4985  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:51:28 d2.utils.events]: eta: 6:53:26  iter: 250499  total_loss: 0.082  loss_cls: 0.051  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4986  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:51:38 d2.utils.events]: eta: 6:53:40  iter: 250519  total_loss: 0.065  loss_cls: 0.041  loss_box_reg: 0.029  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4990  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:51:49 d2.utils.events]: eta: 6:53:48  iter: 250539  total_loss: 0.125  loss_cls: 0.068  loss_box_reg: 0.036  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4994  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:51:59 d2.utils.events]: eta: 6:53:38  iter: 250559  total_loss: 0.107  loss_cls: 0.071  loss_box_reg: 0.039  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4995  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:52:09 d2.utils.events]: eta: 6:53:30  iter: 250579  total_loss: 0.068  loss_cls: 0.040  loss_box_reg: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4996  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:52:19 d2.utils.events]: eta: 6:53:52  iter: 250599  total_loss: 0.067  loss_cls: 0.028  loss_box_reg: 0.028  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5001  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:52:29 d2.utils.events]: eta: 6:53:21  iter: 250619  total_loss: 0.060  loss_cls: 0.024  loss_box_reg: 0.034  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5000  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:52:39 d2.utils.events]: eta: 6:53:11  iter: 250639  total_loss: 0.083  loss_cls: 0.047  loss_box_reg: 0.025  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5001  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:52:49 d2.utils.events]: eta: 6:52:30  iter: 250659  total_loss: 0.158  loss_cls: 0.103  loss_box_reg: 0.031  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4996  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:52:59 d2.utils.events]: eta: 6:52:02  iter: 250679  total_loss: 0.104  loss_cls: 0.048  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4995  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:53:09 d2.utils.events]: eta: 6:51:52  iter: 250699  total_loss: 0.090  loss_cls: 0.038  loss_box_reg: 0.037  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4994  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:53:18 d2.utils.events]: eta: 6:51:32  iter: 250719  total_loss: 0.129  loss_cls: 0.084  loss_box_reg: 0.031  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4990  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:53:28 d2.utils.events]: eta: 6:51:14  iter: 250739  total_loss: 0.085  loss_cls: 0.035  loss_box_reg: 0.037  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4988  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:53:39 d2.utils.events]: eta: 6:51:22  iter: 250759  total_loss: 0.096  loss_cls: 0.042  loss_box_reg: 0.029  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4993  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:53:49 d2.utils.events]: eta: 6:51:12  iter: 250779  total_loss: 0.118  loss_cls: 0.067  loss_box_reg: 0.032  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4995  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:53:59 d2.utils.events]: eta: 6:51:37  iter: 250799  total_loss: 0.112  loss_cls: 0.065  loss_box_reg: 0.034  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4999  data_time: 0.0018  lr: 0.000003  max_mem: 4055M
# [02/27 08:54:09 d2.utils.events]: eta: 6:50:52  iter: 250819  total_loss: 0.086  loss_cls: 0.056  loss_box_reg: 0.034  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4993  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:54:19 d2.utils.events]: eta: 6:51:20  iter: 250839  total_loss: 0.227  loss_cls: 0.185  loss_box_reg: 0.033  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4994  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:54:29 d2.utils.events]: eta: 6:51:16  iter: 250859  total_loss: 0.105  loss_cls: 0.034  loss_box_reg: 0.037  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4994  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:54:38 d2.utils.events]: eta: 6:50:54  iter: 250879  total_loss: 0.066  loss_cls: 0.022  loss_box_reg: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4990  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:54:48 d2.utils.events]: eta: 6:50:47  iter: 250899  total_loss: 0.072  loss_cls: 0.023  loss_box_reg: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4991  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:54:58 d2.utils.events]: eta: 6:50:30  iter: 250919  total_loss: 0.154  loss_cls: 0.077  loss_box_reg: 0.040  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4990  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:55:08 d2.utils.events]: eta: 6:49:38  iter: 250939  total_loss: 0.096  loss_cls: 0.060  loss_box_reg: 0.033  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4988  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:55:18 d2.utils.events]: eta: 6:49:32  iter: 250959  total_loss: 0.073  loss_cls: 0.028  loss_box_reg: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4988  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:55:28 d2.utils.events]: eta: 6:49:26  iter: 250979  total_loss: 0.085  loss_cls: 0.040  loss_box_reg: 0.029  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4989  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:55:38 d2.utils.events]: eta: 6:49:50  iter: 250999  total_loss: 0.168  loss_cls: 0.108  loss_box_reg: 0.044  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4992  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:55:49 d2.utils.events]: eta: 6:50:06  iter: 251019  total_loss: 0.124  loss_cls: 0.099  loss_box_reg: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4993  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:55:58 d2.utils.events]: eta: 6:50:33  iter: 251039  total_loss: 0.181  loss_cls: 0.144  loss_box_reg: 0.029  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4990  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:56:08 d2.utils.events]: eta: 6:51:03  iter: 251059  total_loss: 0.100  loss_cls: 0.042  loss_box_reg: 0.029  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4992  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:56:18 d2.utils.events]: eta: 6:51:02  iter: 251079  total_loss: 0.103  loss_cls: 0.071  loss_box_reg: 0.037  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4991  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:56:28 d2.utils.events]: eta: 6:50:52  iter: 251099  total_loss: 0.104  loss_cls: 0.064  loss_box_reg: 0.039  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4992  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:56:39 d2.utils.events]: eta: 6:50:53  iter: 251119  total_loss: 0.132  loss_cls: 0.088  loss_box_reg: 0.034  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4994  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:56:49 d2.utils.events]: eta: 6:50:42  iter: 251139  total_loss: 0.084  loss_cls: 0.054  loss_box_reg: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4993  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:56:58 d2.utils.events]: eta: 6:50:33  iter: 251159  total_loss: 0.113  loss_cls: 0.072  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4992  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:57:08 d2.utils.events]: eta: 6:50:28  iter: 251179  total_loss: 0.110  loss_cls: 0.060  loss_box_reg: 0.028  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4990  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:57:18 d2.utils.events]: eta: 6:50:31  iter: 251199  total_loss: 0.071  loss_cls: 0.033  loss_box_reg: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4990  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:57:28 d2.utils.events]: eta: 6:50:02  iter: 251219  total_loss: 0.082  loss_cls: 0.046  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4988  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:57:38 d2.utils.events]: eta: 6:49:42  iter: 251239  total_loss: 0.119  loss_cls: 0.082  loss_box_reg: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4986  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:57:48 d2.utils.events]: eta: 6:49:32  iter: 251259  total_loss: 0.203  loss_cls: 0.140  loss_box_reg: 0.035  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4987  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:57:58 d2.utils.events]: eta: 6:49:24  iter: 251279  total_loss: 0.163  loss_cls: 0.083  loss_box_reg: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4986  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:58:08 d2.utils.events]: eta: 6:49:04  iter: 251299  total_loss: 0.159  loss_cls: 0.097  loss_box_reg: 0.036  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4988  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:58:18 d2.utils.events]: eta: 6:48:58  iter: 251319  total_loss: 0.199  loss_cls: 0.085  loss_box_reg: 0.053  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4988  data_time: 0.0018  lr: 0.000003  max_mem: 4055M
# [02/27 08:58:28 d2.utils.events]: eta: 6:48:03  iter: 251339  total_loss: 0.181  loss_cls: 0.125  loss_box_reg: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4986  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:58:38 d2.utils.events]: eta: 6:48:23  iter: 251359  total_loss: 0.070  loss_cls: 0.039  loss_box_reg: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4987  data_time: 0.0018  lr: 0.000003  max_mem: 4055M
# [02/27 08:58:48 d2.utils.events]: eta: 6:47:33  iter: 251379  total_loss: 0.159  loss_cls: 0.114  loss_box_reg: 0.028  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4986  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:58:58 d2.utils.events]: eta: 6:47:10  iter: 251399  total_loss: 0.097  loss_cls: 0.062  loss_box_reg: 0.032  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4986  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:59:07 d2.utils.events]: eta: 6:46:53  iter: 251419  total_loss: 0.118  loss_cls: 0.073  loss_box_reg: 0.032  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4985  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:59:17 d2.utils.events]: eta: 6:46:32  iter: 251439  total_loss: 0.082  loss_cls: 0.043  loss_box_reg: 0.034  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4984  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:59:27 d2.utils.events]: eta: 6:46:22  iter: 251459  total_loss: 0.105  loss_cls: 0.058  loss_box_reg: 0.038  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4985  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:59:38 d2.utils.events]: eta: 6:46:38  iter: 251479  total_loss: 0.066  loss_cls: 0.030  loss_box_reg: 0.025  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4988  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 08:59:48 d2.utils.events]: eta: 6:46:20  iter: 251499  total_loss: 0.080  loss_cls: 0.039  loss_box_reg: 0.037  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4986  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 08:59:58 d2.utils.events]: eta: 6:46:15  iter: 251519  total_loss: 0.109  loss_cls: 0.054  loss_box_reg: 0.031  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4987  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:00:08 d2.utils.events]: eta: 6:46:45  iter: 251539  total_loss: 0.180  loss_cls: 0.119  loss_box_reg: 0.037  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4991  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:00:18 d2.utils.events]: eta: 6:46:34  iter: 251559  total_loss: 0.095  loss_cls: 0.051  loss_box_reg: 0.034  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4990  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:00:28 d2.utils.events]: eta: 6:45:52  iter: 251579  total_loss: 0.104  loss_cls: 0.056  loss_box_reg: 0.036  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4988  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 09:00:38 d2.utils.events]: eta: 6:45:23  iter: 251599  total_loss: 0.102  loss_cls: 0.059  loss_box_reg: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4989  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 09:00:48 d2.utils.events]: eta: 6:45:35  iter: 251619  total_loss: 0.079  loss_cls: 0.043  loss_box_reg: 0.029  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4989  data_time: 0.0018  lr: 0.000003  max_mem: 4055M
# [02/27 09:00:58 d2.utils.events]: eta: 6:45:46  iter: 251639  total_loss: 0.088  loss_cls: 0.038  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4990  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:01:08 d2.utils.events]: eta: 6:46:04  iter: 251659  total_loss: 0.091  loss_cls: 0.041  loss_box_reg: 0.025  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4991  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:01:18 d2.utils.events]: eta: 6:45:47  iter: 251679  total_loss: 0.078  loss_cls: 0.029  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4991  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:01:28 d2.utils.events]: eta: 6:45:49  iter: 251699  total_loss: 0.084  loss_cls: 0.037  loss_box_reg: 0.028  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4991  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 09:01:39 d2.utils.events]: eta: 6:46:07  iter: 251719  total_loss: 0.080  loss_cls: 0.034  loss_box_reg: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4994  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 09:01:48 d2.utils.events]: eta: 6:45:58  iter: 251739  total_loss: 0.078  loss_cls: 0.033  loss_box_reg: 0.028  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4992  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:01:59 d2.utils.events]: eta: 6:45:33  iter: 251759  total_loss: 0.227  loss_cls: 0.133  loss_box_reg: 0.037  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 0.4993  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:02:09 d2.utils.events]: eta: 6:45:29  iter: 251779  total_loss: 0.086  loss_cls: 0.051  loss_box_reg: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4994  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 09:02:19 d2.utils.events]: eta: 6:45:28  iter: 251799  total_loss: 0.150  loss_cls: 0.124  loss_box_reg: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4996  data_time: 0.0015  lr: 0.000003  max_mem: 4055M
# [02/27 09:02:29 d2.utils.events]: eta: 6:45:27  iter: 251819  total_loss: 0.123  loss_cls: 0.078  loss_box_reg: 0.029  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4996  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:02:39 d2.utils.events]: eta: 6:45:06  iter: 251839  total_loss: 0.244  loss_cls: 0.221  loss_box_reg: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4995  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:02:49 d2.utils.events]: eta: 6:44:56  iter: 251859  total_loss: 0.104  loss_cls: 0.048  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4996  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:02:59 d2.utils.events]: eta: 6:44:46  iter: 251879  total_loss: 0.120  loss_cls: 0.047  loss_box_reg: 0.031  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4995  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 09:03:09 d2.utils.events]: eta: 6:44:36  iter: 251899  total_loss: 0.127  loss_cls: 0.063  loss_box_reg: 0.031  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4995  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:03:19 d2.utils.events]: eta: 6:44:27  iter: 251919  total_loss: 0.122  loss_cls: 0.070  loss_box_reg: 0.031  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4994  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:03:28 d2.utils.events]: eta: 6:44:23  iter: 251939  total_loss: 0.082  loss_cls: 0.043  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4992  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:03:38 d2.utils.events]: eta: 6:44:13  iter: 251959  total_loss: 0.075  loss_cls: 0.045  loss_box_reg: 0.024  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4992  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:03:48 d2.utils.events]: eta: 6:43:50  iter: 251979  total_loss: 0.074  loss_cls: 0.042  loss_box_reg: 0.025  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4991  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:03:58 d2.utils.events]: eta: 6:43:07  iter: 251999  total_loss: 0.083  loss_cls: 0.057  loss_box_reg: 0.025  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4990  data_time: 0.0015  lr: 0.000003  max_mem: 4055M
# [02/27 09:04:08 d2.utils.events]: eta: 6:43:02  iter: 252019  total_loss: 0.077  loss_cls: 0.031  loss_box_reg: 0.032  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4991  data_time: 0.0015  lr: 0.000003  max_mem: 4055M
# [02/27 09:04:19 d2.utils.events]: eta: 6:43:07  iter: 252039  total_loss: 0.065  loss_cls: 0.035  loss_box_reg: 0.021  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4993  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:04:29 d2.utils.events]: eta: 6:42:42  iter: 252059  total_loss: 0.111  loss_cls: 0.075  loss_box_reg: 0.039  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4992  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 09:04:39 d2.utils.events]: eta: 6:42:44  iter: 252079  total_loss: 0.110  loss_cls: 0.057  loss_box_reg: 0.035  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4994  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 09:04:49 d2.utils.events]: eta: 6:42:34  iter: 252099  total_loss: 0.083  loss_cls: 0.039  loss_box_reg: 0.031  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4993  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:04:59 d2.utils.events]: eta: 6:42:23  iter: 252119  total_loss: 0.064  loss_cls: 0.030  loss_box_reg: 0.025  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4995  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 09:05:09 d2.utils.events]: eta: 6:42:01  iter: 252139  total_loss: 0.082  loss_cls: 0.049  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4994  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:05:19 d2.utils.events]: eta: 6:42:07  iter: 252159  total_loss: 0.109  loss_cls: 0.041  loss_box_reg: 0.031  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4995  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:05:29 d2.utils.events]: eta: 6:42:22  iter: 252179  total_loss: 0.068  loss_cls: 0.034  loss_box_reg: 0.034  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.4996  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 09:05:39 d2.utils.events]: eta: 6:41:59  iter: 252199  total_loss: 0.081  loss_cls: 0.038  loss_box_reg: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4995  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 09:05:49 d2.utils.events]: eta: 6:42:07  iter: 252219  total_loss: 0.088  loss_cls: 0.053  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.4995  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# ...
# [02/27 15:33:42 d2.utils.events]: eta: 0:11:31  iter: 298619  total_loss: 0.066  loss_cls: 0.031  loss_box_reg: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:33:52 d2.utils.events]: eta: 0:11:21  iter: 298639  total_loss: 0.092  loss_cls: 0.046  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:34:02 d2.utils.events]: eta: 0:11:11  iter: 298659  total_loss: 0.094  loss_cls: 0.057  loss_box_reg: 0.032  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:34:12 d2.utils.events]: eta: 0:11:01  iter: 298679  total_loss: 0.067  loss_cls: 0.040  loss_box_reg: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:34:22 d2.utils.events]: eta: 0:10:51  iter: 298699  total_loss: 0.112  loss_cls: 0.043  loss_box_reg: 0.037  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:34:32 d2.utils.events]: eta: 0:10:41  iter: 298719  total_loss: 0.097  loss_cls: 0.066  loss_box_reg: 0.043  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 0.5006  data_time: 0.0015  lr: 0.000003  max_mem: 4055M
# [02/27 15:34:42 d2.utils.events]: eta: 0:10:31  iter: 298739  total_loss: 0.065  loss_cls: 0.022  loss_box_reg: 0.035  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:34:52 d2.utils.events]: eta: 0:10:22  iter: 298759  total_loss: 0.083  loss_cls: 0.054  loss_box_reg: 0.033  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:35:02 d2.utils.events]: eta: 0:10:12  iter: 298779  total_loss: 0.074  loss_cls: 0.045  loss_box_reg: 0.025  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0015  lr: 0.000003  max_mem: 4055M
# [02/27 15:35:12 d2.utils.events]: eta: 0:10:02  iter: 298799  total_loss: 0.065  loss_cls: 0.027  loss_box_reg: 0.031  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:35:22 d2.utils.events]: eta: 0:09:52  iter: 298819  total_loss: 0.064  loss_cls: 0.032  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:35:32 d2.utils.events]: eta: 0:09:41  iter: 298839  total_loss: 0.088  loss_cls: 0.073  loss_box_reg: 0.021  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:35:41 d2.utils.events]: eta: 0:09:31  iter: 298859  total_loss: 0.072  loss_cls: 0.045  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:35:52 d2.utils.events]: eta: 0:09:21  iter: 298879  total_loss: 0.057  loss_cls: 0.023  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:36:02 d2.utils.events]: eta: 0:09:11  iter: 298899  total_loss: 0.100  loss_cls: 0.057  loss_box_reg: 0.034  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:36:12 d2.utils.events]: eta: 0:09:01  iter: 298919  total_loss: 0.113  loss_cls: 0.081  loss_box_reg: 0.034  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:36:22 d2.utils.events]: eta: 0:08:52  iter: 298939  total_loss: 0.106  loss_cls: 0.062  loss_box_reg: 0.040  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:36:32 d2.utils.events]: eta: 0:08:41  iter: 298959  total_loss: 0.078  loss_cls: 0.024  loss_box_reg: 0.036  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:36:41 d2.utils.events]: eta: 0:08:31  iter: 298979  total_loss: 0.098  loss_cls: 0.064  loss_box_reg: 0.031  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:36:52 d2.utils.events]: eta: 0:08:21  iter: 298999  total_loss: 0.093  loss_cls: 0.033  loss_box_reg: 0.037  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:37:01 d2.utils.events]: eta: 0:08:11  iter: 299019  total_loss: 0.085  loss_cls: 0.035  loss_box_reg: 0.034  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:37:11 d2.utils.events]: eta: 0:08:01  iter: 299039  total_loss: 0.074  loss_cls: 0.028  loss_box_reg: 0.033  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:37:21 d2.utils.events]: eta: 0:07:51  iter: 299059  total_loss: 0.057  loss_cls: 0.023  loss_box_reg: 0.028  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:37:32 d2.utils.events]: eta: 0:07:41  iter: 299079  total_loss: 0.088  loss_cls: 0.037  loss_box_reg: 0.044  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0015  lr: 0.000003  max_mem: 4055M
# [02/27 15:37:42 d2.utils.events]: eta: 0:07:31  iter: 299099  total_loss: 0.098  loss_cls: 0.052  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:37:52 d2.utils.events]: eta: 0:07:21  iter: 299119  total_loss: 0.093  loss_cls: 0.057  loss_box_reg: 0.028  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:38:02 d2.utils.events]: eta: 0:07:11  iter: 299139  total_loss: 0.054  loss_cls: 0.024  loss_box_reg: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:38:12 d2.utils.events]: eta: 0:07:01  iter: 299159  total_loss: 0.056  loss_cls: 0.022  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:38:22 d2.utils.events]: eta: 0:06:51  iter: 299179  total_loss: 0.116  loss_cls: 0.066  loss_box_reg: 0.034  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:38:32 d2.utils.events]: eta: 0:06:41  iter: 299199  total_loss: 0.100  loss_cls: 0.047  loss_box_reg: 0.035  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:38:42 d2.utils.events]: eta: 0:06:31  iter: 299219  total_loss: 0.050  loss_cls: 0.020  loss_box_reg: 0.018  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:38:52 d2.utils.events]: eta: 0:06:21  iter: 299239  total_loss: 0.064  loss_cls: 0.021  loss_box_reg: 0.029  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:39:02 d2.utils.events]: eta: 0:06:11  iter: 299259  total_loss: 0.065  loss_cls: 0.022  loss_box_reg: 0.033  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:39:11 d2.utils.events]: eta: 0:06:01  iter: 299279  total_loss: 0.079  loss_cls: 0.030  loss_box_reg: 0.033  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:39:21 d2.utils.events]: eta: 0:05:51  iter: 299299  total_loss: 0.093  loss_cls: 0.039  loss_box_reg: 0.031  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:39:31 d2.utils.events]: eta: 0:05:41  iter: 299319  total_loss: 0.081  loss_cls: 0.038  loss_box_reg: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:39:41 d2.utils.events]: eta: 0:05:31  iter: 299339  total_loss: 0.057  loss_cls: 0.032  loss_box_reg: 0.018  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:39:51 d2.utils.events]: eta: 0:05:21  iter: 299359  total_loss: 0.079  loss_cls: 0.028  loss_box_reg: 0.036  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:40:01 d2.utils.events]: eta: 0:05:11  iter: 299379  total_loss: 0.057  loss_cls: 0.017  loss_box_reg: 0.023  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:40:11 d2.utils.events]: eta: 0:05:01  iter: 299399  total_loss: 0.096  loss_cls: 0.044  loss_box_reg: 0.039  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:40:22 d2.utils.events]: eta: 0:04:51  iter: 299419  total_loss: 0.097  loss_cls: 0.047  loss_box_reg: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:40:31 d2.utils.events]: eta: 0:04:40  iter: 299439  total_loss: 0.107  loss_cls: 0.066  loss_box_reg: 0.044  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:40:42 d2.utils.events]: eta: 0:04:31  iter: 299459  total_loss: 0.084  loss_cls: 0.032  loss_box_reg: 0.038  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:40:52 d2.utils.events]: eta: 0:04:21  iter: 299479  total_loss: 0.076  loss_cls: 0.056  loss_box_reg: 0.020  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:41:02 d2.utils.events]: eta: 0:04:11  iter: 299499  total_loss: 0.144  loss_cls: 0.103  loss_box_reg: 0.024  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:41:12 d2.utils.events]: eta: 0:04:01  iter: 299519  total_loss: 0.090  loss_cls: 0.043  loss_box_reg: 0.029  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:41:22 d2.utils.events]: eta: 0:03:51  iter: 299539  total_loss: 0.065  loss_cls: 0.026  loss_box_reg: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:41:31 d2.utils.events]: eta: 0:03:40  iter: 299559  total_loss: 0.098  loss_cls: 0.037  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:41:41 d2.utils.events]: eta: 0:03:31  iter: 299579  total_loss: 0.061  loss_cls: 0.039  loss_box_reg: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:41:51 d2.utils.events]: eta: 0:03:20  iter: 299599  total_loss: 0.096  loss_cls: 0.036  loss_box_reg: 0.039  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:42:01 d2.utils.events]: eta: 0:03:10  iter: 299619  total_loss: 0.084  loss_cls: 0.024  loss_box_reg: 0.034  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:42:12 d2.utils.events]: eta: 0:03:01  iter: 299639  total_loss: 0.084  loss_cls: 0.045  loss_box_reg: 0.035  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:42:22 d2.utils.events]: eta: 0:02:51  iter: 299659  total_loss: 0.077  loss_cls: 0.041  loss_box_reg: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:42:32 d2.utils.events]: eta: 0:02:41  iter: 299679  total_loss: 0.082  loss_cls: 0.044  loss_box_reg: 0.033  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:42:42 d2.utils.events]: eta: 0:02:31  iter: 299699  total_loss: 0.096  loss_cls: 0.069  loss_box_reg: 0.023  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0018  lr: 0.000003  max_mem: 4055M
# [02/27 15:42:52 d2.utils.events]: eta: 0:02:21  iter: 299719  total_loss: 0.063  loss_cls: 0.022  loss_box_reg: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:43:02 d2.utils.events]: eta: 0:02:10  iter: 299739  total_loss: 0.087  loss_cls: 0.041  loss_box_reg: 0.042  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:43:12 d2.utils.events]: eta: 0:02:00  iter: 299759  total_loss: 0.107  loss_cls: 0.064  loss_box_reg: 0.042  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:43:22 d2.utils.events]: eta: 0:01:50  iter: 299779  total_loss: 0.106  loss_cls: 0.080  loss_box_reg: 0.035  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:43:32 d2.utils.events]: eta: 0:01:40  iter: 299799  total_loss: 0.053  loss_cls: 0.020  loss_box_reg: 0.021  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:43:42 d2.utils.events]: eta: 0:01:30  iter: 299819  total_loss: 0.079  loss_cls: 0.043  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:43:52 d2.utils.events]: eta: 0:01:20  iter: 299839  total_loss: 0.103  loss_cls: 0.068  loss_box_reg: 0.041  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:44:02 d2.utils.events]: eta: 0:01:10  iter: 299859  total_loss: 0.098  loss_cls: 0.053  loss_box_reg: 0.041  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:44:12 d2.utils.events]: eta: 0:01:00  iter: 299879  total_loss: 0.073  loss_cls: 0.030  loss_box_reg: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:44:21 d2.utils.events]: eta: 0:00:50  iter: 299899  total_loss: 0.096  loss_cls: 0.054  loss_box_reg: 0.040  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:44:31 d2.utils.events]: eta: 0:00:40  iter: 299919  total_loss: 0.050  loss_cls: 0.034  loss_box_reg: 0.023  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:44:42 d2.utils.events]: eta: 0:00:30  iter: 299939  total_loss: 0.067  loss_cls: 0.035  loss_box_reg: 0.032  loss_rpn_cls: 0.000  loss_rpn_loc: 0.001  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:44:52 d2.utils.events]: eta: 0:00:20  iter: 299959  total_loss: 0.092  loss_cls: 0.050  loss_box_reg: 0.029  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:45:02 d2.utils.events]: eta: 0:00:10  iter: 299979  total_loss: 0.101  loss_cls: 0.063  loss_box_reg: 0.038  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0017  lr: 0.000003  max_mem: 4055M
# [02/27 15:45:17 d2.utils.events]: eta: 0:00:00  iter: 299999  total_loss: 0.065  loss_cls: 0.034  loss_box_reg: 0.022  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 0.5006  data_time: 0.0016  lr: 0.000003  max_mem: 4055M
# [02/27 15:45:17 d2.engine.hooks]: Overall training speed: 49997 iterations in 6:57:07 (0.5006 s / it)
# [02/27 15:45:17 d2.engine.hooks]: Total training time: 6:57:57 (0:00:49 on hooks)

# %%
# Look at training curves in tensorboard:
# %load_ext tensorboard
# %tensorboard --logdir output
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 3590), started 10:56:59 ago. (Use '!kill 3590' to kill it.)
#       <iframe id="tensorboard-frame-a5ec56046f6eec3b" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a5ec56046f6eec3b");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.3   # set the testing threshold for this model
cfg.DATASETS.TEST = ("animals_val", )
predictor = DefaultPredictor(cfg)
dataset_dicts = get_animals_dicts("animals_val")

# %%
from detectron2.utils.visualizer import ColorMode

for d in random.sample(dataset_dicts, 50):    
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1],
                   metadata=animal_metadata, 
                   scale=2   # remove the colors of unsegmented pixels
    )
    v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    cv2.imshow("",v.get_image()[:, :, ::-1])
    cv2.waitKey(0) # waits until a key is pressed
    cv2.destroyAllWindows() # destroys the window showing image

# %%
# cfg

# %%
("animals_val", )
# Out:
# ('animals_val',)

# %%
x = None
for d in random.sample(dataset_dicts, 1):    
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    x = outputs
    print(x)
#     v = Visualizer(im[:, :, ::-1],
#                    metadata=animal_metadata, 
#                    scale=2   # remove the colors of unsegmented pixels
#     )
#     v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
#     cv2.imshow("",v.get_image()[:, :, ::-1])
#     cv2.waitKey(0) # waits until a key is pressed
#     cv2.destroyAllWindows() # destroys the window showing image
# Out:
# {'instances': Instances(num_instances=3, image_height=404, image_width=720, fields=[pred_boxes: Boxes(tensor([[ 79.4528, 190.4118, 154.0742, 354.6513],
#         [295.7289, 258.3346, 354.7699, 337.0996],
#         [665.9459, 345.0436, 719.9958, 402.2468]], device='cuda:0')), scores: tensor([0.8789, 0.4466, 0.3125], device='cuda:0'), pred_classes: tensor([14,  5, 15], device='cuda:0')])}

# %%
x['instances']
# Out:
# Instances(num_instances=3, image_height=404, image_width=720, fields=[pred_boxes: Boxes(tensor([[ 79.4528, 190.4118, 154.0742, 354.6513],
#         [295.7289, 258.3346, 354.7699, 337.0996],
#         [665.9459, 345.0436, 719.9958, 402.2468]], device='cuda:0')), scores: tensor([0.8789, 0.4466, 0.3125], device='cuda:0'), pred_classes: tensor([14,  5, 15], device='cuda:0')])

# %% [markdown]
# x['instances'].pred_boxes[0].tensor.tolist()[0]

# %%
x['instances'].scores[0].tolist()
# Out:
# 0.8789103031158447

# %%
x['instances'].pred_classes[0].tolist()
# Out:
# 14
